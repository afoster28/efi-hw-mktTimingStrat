# %% [markdown]
# # Principal Component Analysis - S&P500 Equity Exploration
#
# Equity and Fixed Income project
#
# Authors: Adam Foster, Maciej Staniszewski
#
# PCA is a dimensionality reduction method whereby multiple variables in a large dataset are transformed into a smaller set of variables, maintaining most of the information in the large dataset. Resulting variables are easier to explore and analyse and are less computationally expensive to process.
#
# This exercise covers a practical demonstration of this approach, as well as its application in determining key single name equity drivers of S&P500 index returns.

# %% [markdown]
# ## Prerequisites
#
# We recommend cloning one of the following Github repos to run this code locally and access the dataset used subsequently:
#
# https://github.com/Staneesh/efi-pca
#
# https://github.com/afoster28/efi-pca
#
# Make sure to run the following command to install all required packages:
# `pip install -r requirements.txt`
#
# This includes:
# * `numpy` for basic mathematical operations
# * `pandas` for dataset manipulations
# * `ipykernel` Jupyter kernel for Python code execution
# * `matplotlib` for data visualisation with plots
# * `yfinance` for financial data from Yahoo Finance
#
# Dataset to be included in run folder (available on Github): `all_stocks_5yr.csv`
#
# Otherwise, simply view the ipynb or html files which include markdown commentary and saved output

# %% [markdown]
# ## PCA Methodology
#
# ### Step 1 - Standardisation
#
# Standardisation involves the normalisation using mean and standard deviation and makes varying domains comparable. This prevents variables with larger domains dwarfing the impact of smaller domains, reducing bias.
#
# $z = \frac{value - mean}{standard deviation}$
#
# ### Step 2 - Covariance Matrix
#
# In searching for all possible relationships between the variables and their joint variance, a covariance matrix is created. For $n$ variables, an $n\times n$ covariance matrix is formed.
#
# We can observe a couple of interesting facts about the covariance matrix:
# * Diagonal elements of the covariance matrix describe the variance of individual variables. This is because they contain information about the variability of the pair of values $(e1, e1)$ which is essentially the same as the variability of $e1$ for some variable $e1$.
# * Another observation is that the matrix should be symmetrical about the diagonal. This means that elements $(e1, e2)$ vary in the same exact way as elements $(e2, e1)$. Note: that python libraries will raise a warning if the covariance matrix does not have that property.
#
# ### Step 3 - Eigendecomposition
#
# Principal components are new variables that are constructed as linear combinations of the initial variables. These combinations are done in such a way that the principal components are uncorrelated and most of the information within the initial variables (and therefore the variance) is compressed into the first components.
#
# Across all principal components, the same information is maintained. The advantage is that the minimum amount of information is lost when removing the least important components, hence a large proportion of the data can be represented by few components - they pick up the maximal amount of variance.
#
# The first principal component is calculated to maximise the average of the squared distances from projected points to the origin. The second one is calculated the same way, provided it is uncorrelated with and therefore orthogonal to the first component. This can be continued for the number of dimensions of the data and each component has an associated eigenvector-eigenvalue pair. Eigenvectors describe the direction of the axes where there is the most variance and eigenvalues show the amount of variance carried. Ranking eigenvectors by eigenvalues in descending order shows the principal components in order of significance. The eigenvalue relative to the sum of eigenvalues denotes the percentage of variance covered by the associated principal component.
#
# #### Methodology
#
# A point $x$ gets projected onto a unit vector $u$, a new point $x'$ is created whose magnitude is calculated by the inner product between $x$ and $u$: $x' = (x^{T}u)u$.
#
# $(x^{T}u)^{2}$ can be thought of as the amount of information preserved and is maximal when $x$ is parallel to $u$ and minimal when $x$ is orthogonal to $u$. PCA is then an optimisation problem whereby it seeks to maximise information preserved subject to the unit vector usage:
#
# $max \sum \limits _{i} (x _{i} ^{T} u)^{2}$ subject to $u^{T} u = 1$
#
# which simplifies to
#
# $max \text{ } u ^{T} C u$ subject to $u^{T} u = 1$ where $C = \frac{1}{n} \sum \limits _{i} x _{i} x _{i} ^{T}$ (covariance matrix)
#
# This can be expressed as a Lagrangean and solved:
#
# $L = u ^{T} C u - \lambda(u^{T} u - 1)$
#
# $2 C u - 2 \lambda u = 0$
#
# $C u = \lambda u$
#
# Therefore, $u$ and $\lambda$ represent eigenvectors and eigenvalues, respectively. The best direction $u_{1}$ to pick is coupled with the eigenvector with the largest eigenvalue $\lambda_{1}$. $u_{2}$ can then be selected such that $u_{2} \perp u_{1}$ with $\lambda_{2}$ and so on.
#
#
# ### Step 4 - Feature Vector
#
# At this stage, a process of elimination occurs based on principal component significance and the resulting components form the feature vector.
#
#
# ### Step 5 - Recast the Data along the PC Axes
#
# Eigenvectors of the feature vector prinicpal components are used to reorient the data from the original axes to the ones represented by the principal components.
#
# $Final Dataset = Feature Vector^{T} \times Standardised Original Dataset^{T}$
#
# This data can be visualised in a more intuitive manner across fewer dimensions.

# %% [markdown]
# ## Simple PCA Decomposition

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We're ready to use them to generate a simple dataset for illustration purposes. We'll implement a data-generating function, the results of which we will use as inputs to our PCA.
#
# Our samples will be drawn from a Gaussian distribution in two dimensions, as follows:

# %%
means = [10, 20]  # Means of marginal distributions
cov = [[25, 5], [5, 5]]  # diagonal covariance
x, y = np.random.multivariate_normal(means, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()

# %% [markdown]
# PCA is based on eigenvalues and eigenvectors which can be computed using `numpy`:

# %%
values, vectors = np.linalg.eig(cov)
values[:5]
# Out:
# array([26.18033989,  3.81966011])

# %%
explained_variances = []
for i in range(len(values)):
    explained_variances.append(values[i] / np.sum(values))
 
print(f"Total explained variance = {np.sum(explained_variances) * 100}%\nIndividual explained variances = {explained_variances}\n")
# Out:
# Total explained variance = 100.0%
# Individual explained variances = [0.872677996249965, 0.12732200375003505]

# %% [markdown]
# We can see, that the variance is explained fully by the first two components. The first component explains over 87% of variance in the data. This is as expected, because the data was generated using two variables only.

# %%
# Let's define a simple function that will format a vector for later printing
def print_vector(v):
    return( "({}, {})" ).format(round(v[ 0 ], 2), round(v[ 1 ], 2))

# %%
# Eigenvectors obtained through the decomposition:
for i, v in enumerate(zip( vectors, values )):
    # Using the small helper function defined above
    print( f"Eigenvector {i}:\t{print_vector(v[ 0 ])} with value {round(v[ 1 ], 2)}" )
# Out:
# Eigenvector 0:	(0.97, -0.23) with value 26.18
# Eigenvector 1:	(0.23, 0.97) with value 3.82

# %% [markdown]
# These eigenvectors are two-dimensional. We can easily plot them over the original data set as follows:

# %%
origin = [[means[0], means[0]], [means[1], means[1]]]

fig, ax = plt.subplots(nrows=1, ncols=2)

# Plotting actual eigenvectors on the left
ax[ 0 ].plot(x, y, 'x', zorder=1)
ax[ 0 ].axis('equal')
ax[ 0 ].set_title('Eigenvectors of the original data set')
ax[ 0 ].quiver(*origin, vectors[ 0 ], vectors[ 1 ], 
            color=['r','b'], scale=5, zorder=2)

# Plotting scaled eigenvectors - "loadings" on the right. For details see references.
ax[ 1 ].plot(x, y, 'x', zorder=1)
ax[ 1 ].axis('equal')
# Loadings are eigenvectors which are scaled by the square root of the explained variance 
ax[ 1 ].set_title('Loadings of the original data set')
ax[ 1 ].quiver(*origin, 
               np.dot( vectors[ 0 ], np.sqrt( explained_variances[ 0 ] ) ), 
               np.dot( vectors[ 1 ], np.sqrt( explained_variances[ 1 ] ) ),               
               color=['r','b'], scale=5, zorder=2)

fig.set_figwidth(20)
plt.show()

# %% [markdown]
# The first (red) eigenvector is in fact explaining most of the variance as computed above. The horizontal dispersion is dominant and receives more weight through the eigenvalue. The vertical dispersion is smaller in comparison and less important overall. Note how the directions of eigenvectors appropriately reflect the tilt introduced by the correlation structure.

# %% [markdown]
# ## Data Preparation: S&P500 & Equities
#
# We will now download actual financial data observed in the market and apply PCA to it to to arrive at some findings.
#
# A good example of features varying together is a set of underliers of an equity index. One of the most relevant ones is the **S&P500** (Standard and Poor's 500). It captures cumulative performance of the 500 largest US equities that trade in the US.
#
# We will use PCA to reduce the dimensionality of the dataset, identifying meaningful principal components of the 500 equities. We will also identify main drivers of S&P500 returns.
#
# We downloaded 5-year historical data containing information about stock prices of all S&P500 underliers between 2013-2018 from Kaggle (link is in the References section). We will use this dataset for our empirical study.
#
# We use `pandas` to load the dataset:

# %%
stocks = pd.read_csv('all_stocks_5yr.csv')
stocks.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
stocks.tail()
# Out:
#               date   open   high    low  close   volume Name
# 619035  2018-02-01  76.84  78.27  76.69  77.82  2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78  2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83  2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27  4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86  4534912  ZTS

# %% [markdown]
# We are interested in the ***close*** column to reflect the price of a stock.

# %%
stocks = stocks[['date', 'close', 'Name']]
unique_names = pd.unique(stocks.loc[:,'Name'])

# %% [markdown]
# Let's load the actual S&P500 prices for the same period:

# %%
import yfinance as yf
snp = yf.download("%5EGSPC", start="2013-02-08", end="2018-02-07")
snp.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-02-08  1509.390015  1518.310059  1509.390015  1517.930054  1517.930054
# 2013-02-11  1517.930054  1518.310059  1513.609985  1517.010010  1517.010010
# 2013-02-12  1517.010010  1522.290039  1515.609985  1519.430054  1519.430054
# 2013-02-13  1519.430054  1524.689941  1515.930054  1520.329956  1520.329956
# 2013-02-14  1520.329956  1523.140015  1514.020020  1521.380005  1521.380005
#
#                 Volume
# Date
# 2013-02-08  2986150000
# 2013-02-11  2684100000
# 2013-02-12  3414370000
# 2013-02-13  3385880000
# 2013-02-14  3759740000

# %%
snp = snp[['Close']]
snp.tail()
# Out:
#                   Close
# Date
# 2018-01-31  2823.810059
# 2018-02-01  2821.979980
# 2018-02-02  2762.129883
# 2018-02-05  2648.939941
# 2018-02-06  2695.139893

# %% [markdown]
# S&P data is not loaded for days between 2018-01-30 and 2018-02-07. We will trim individual stock prices scope to align with that limitation:

# %%
stocks = stocks[stocks['date'] <= '2018-02-06']
stocks.tail()
# Out:
#               date  close Name
# 619034  2018-01-31  76.73  ZTS
# 619035  2018-02-01  77.82  ZTS
# 619036  2018-02-02  76.78  ZTS
# 619037  2018-02-05  73.83  ZTS
# 619038  2018-02-06  73.27  ZTS

# %% [markdown]
# The key step, as discussed before, is to obtain the covariance matrix. We cannot simply call `.cov()` on `stocks`, as all `close` values are in a single column spanning over all stocks that we have in the index. We need to re-pivot the data, so that every stock gets it's own `close` column with stock prices for all dates.

# %%
pivoted_stocks = pd.DataFrame(np.unique(stocks['date']), columns=['date'])
pivoted_stocks.set_index('date')
pivoted_stocks.head()
# Out:
#          date
# 0  2013-02-08
# 1  2013-02-11
# 2  2013-02-12
# 3  2013-02-13
# 4  2013-02-14

# %% [markdown]
# `pivoted_stocks` DataFrame defined above contains all possible unique dates. We will now try to extend this table with new columns for every stock name that we have. The `close` data will be joined to that table based on the date that we already put inside `pivoted_stocks`.
#
# If the code below is taking long (~30 seconds) to compute - **this can be expected** - the dataset we're trying to process is fairly large.

# %%
# Discussed in a comment inside the loop below
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

for name in unique_names:                                                   # For all unique names that we have in the dataset
    prices_for_this_name = stocks[stocks['Name'] == name]                   # Find all prices for a given stock name 
    joined = pivoted_stocks.join(prices_for_this_name.set_index('date'),    # Join those individual stock prices with the list of unique dates
                                 on='date')
    pivoted_stocks[name] = joined['close'].values                           # Add a new column to the dataset with a name representing a stock
    
    #NOTE: Even though we get 'performance warnings', the above line is much much faster than the recommented pd.concat() below:
    #pivoted_stocks = pd.concat([pivoted_stocks, pd.Series(joined['close'].values, name=name)])

# %% [markdown]
# Finally, we can set `date` column as the index in the table and see how well it was populated:

# %%
pivoted_stocks.set_index('date', inplace=True)
pivoted_stocks.tail()
# Out:
#               AAL    AAPL     AAP    ABBV    ABC    ABT     ACN    ADBE  \
# date
# 2018-01-31  54.32  167.43  116.99  112.22  99.67  62.16  160.70  199.76
# 2018-02-01  53.88  167.78  117.29  116.34  99.29  62.18  160.46  199.38
# 2018-02-02  52.10  160.50  113.93  115.17  96.02  61.69  156.90  195.64
# 2018-02-05  49.76  156.49  109.86  109.51  91.90  58.73  151.83  190.27
# 2018-02-06  51.18  163.03  112.20  111.20  91.54  58.86  154.69  194.47
#
#               ADI    ADM  ...   XLNX     XL    XOM   XRAY    XRX    XYL  \
# date                      ...
# 2018-01-31  91.88  42.95  ...  73.02  36.84  87.30  60.81  34.13  72.26
# 2018-02-01  91.65  42.46  ...  72.49  36.79  89.07  60.73  32.75  74.84
# 2018-02-02  89.11  41.43  ...  70.64  38.25  84.53  60.06  31.63  75.66
# 2018-02-05  85.40  40.60  ...  66.97  37.68  79.72  58.54  31.38  72.66
# 2018-02-06  88.54  42.00  ...  68.99  37.34  78.35  58.46  30.85  71.33
#
#               YUM     ZBH   ZION    ZTS
# date
# 2018-01-31  84.59  127.12  54.03  76.73
# 2018-02-01  83.98  128.19  54.98  77.82
# 2018-02-02  82.63  125.79  54.15  76.78
# 2018-02-05  79.80  123.18  51.65  73.83
# 2018-02-06  80.58  122.30  52.52  73.27
#
# [5 rows x 505 columns]

# %% [markdown]
# Now we want to ensure domains across features are comparable; we calculate daily returns for both equity prices and the S&P500 index:

# %%
pivoted_stocks = pivoted_stocks.pct_change().fillna(0)
pivoted_stocks.head()
# Out:
#                  AAL      AAPL       AAP      ABBV       ABC       ABT  \
# date
# 2013-02-08  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-02-11 -0.019661  0.010422 -0.006464 -0.011034 -0.002772 -0.004359
# 2013-02-12 -0.013140 -0.025067  0.002679 -0.011994  0.004277  0.001168
# 2013-02-13  0.027330 -0.001903  0.004707 -0.004235 -0.006814  0.004665
# 2013-02-14 -0.045703 -0.000899 -0.001646  0.036859  0.002787  0.006965
#
#                  ACN      ADBE       ADI       ADM  ...      XLNX        XL  \
# date                                                ...
# 2013-02-08  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2013-02-11 -0.003274 -0.012270  0.008315  0.001985  ... -0.001333  0.002479
# 2013-02-12  0.004106  0.006470  0.004123  0.017503  ...  0.003203  0.003532
# 2013-02-13  0.002590 -0.002057 -0.000216  0.011360  ...  0.005854  0.000352
# 2013-02-14 -0.005846 -0.005153  0.006053  0.007702  ...  0.016931 -0.007037
#
#                  XOM      XRAY       XRX       XYL       YUM       ZBH  \
# date
# 2013-02-08  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-02-11 -0.003724 -0.000700  0.003769  0.013658 -0.011485 -0.002637
# 2013-02-12  0.002039  0.000700 -0.003755  0.017844  0.003098 -0.002776
# 2013-02-13  0.002374  0.004899  0.005025  0.011091 -0.005251  0.007423
# 2013-02-14 -0.001692 -0.003946  0.003750  0.007431 -0.008073  0.004474
#
#                 ZION       ZTS
# date
# 2013-02-08  0.000000  0.000000
# 2013-02-11  0.002900  0.006354
# 2013-02-12  0.011565  0.014432
# 2013-02-13  0.010208 -0.005631
# 2013-02-14 -0.004446 -0.008346
#
# [5 rows x 505 columns]

# %%
# Clear plot area
plt.cla()
plt.clf()

# Show Apple returns as an example
plt.title('Apple stock price returns')
plt.plot(pivoted_stocks['AAPL'])
plt.show()

# %% [markdown]
# Now for the index normalisation:

# %%
snp = snp.pct_change().fillna(0)
snp.head()
# Out:
#                Close
# Date
# 2013-02-08  0.000000
# 2013-02-11 -0.000606
# 2013-02-12  0.001595
# 2013-02-13  0.000592
# 2013-02-14  0.000691

# %%
# Clear plot area
plt.cla()
plt.clf()

# Show S&P500 returns
plt.title('S&P500 index returns')
plt.plot(snp)
plt.show()

# %% [markdown]
# ## Covariance Matrix: Equities
#
# The data has been prepared. We're ready to compute the covariance matrix for this data. We note that it is symmetric as expected, and that the resulting eigenvectors will be orthogonal. As a reminder: the intention is to design principal components on the underlying equities (hence only equities in the covariance matrix) and key equities will then be compared to overall S&P500 results.

# %%
stocks_cov = pivoted_stocks.cov()
stocks_cov.head()
# Out:
#            AAL      AAPL       AAP      ABBV       ABC       ABT       ACN  \
# AAL   0.000504  0.000069  0.000082  0.000085  0.000072  0.000080  0.000076
# AAPL  0.000069  0.000213  0.000035  0.000045  0.000029  0.000048  0.000051
# AAP   0.000082  0.000035  0.000359  0.000068  0.000044  0.000065  0.000047
# ABBV  0.000085  0.000045  0.000068  0.000284  0.000079  0.000090  0.000055
# ABC   0.000072  0.000029  0.000044  0.000079  0.000194  0.000062  0.000044
#
#           ADBE       ADI       ADM  ...      XLNX        XL       XOM  \
# AAL   0.000104  0.000105  0.000075  ...  0.000088  0.000079  0.000043
# AAPL  0.000065  0.000087  0.000040  ...  0.000059  0.000034  0.000041
# AAP   0.000050  0.000056  0.000063  ...  0.000053  0.000042  0.000043
# ABBV  0.000076  0.000073  0.000067  ...  0.000073  0.000042  0.000055
# ABC   0.000044  0.000041  0.000036  ...  0.000037  0.000044  0.000032
#
#           XRAY       XRX       XYL       YUM       ZBH      ZION       ZTS
# AAL   0.000073  0.000105  0.000087  0.000092  0.000074  0.000119  0.000079
# AAPL  0.000044  0.000064  0.000052  0.000060  0.000053  0.000062  0.000049
# AAP   0.000046  0.000069  0.000061  0.000065  0.000054  0.000085  0.000044
# ABBV  0.000061  0.000074  0.000067  0.000054  0.000082  0.000074  0.000089
# ABC   0.000050  0.000049  0.000038  0.000038  0.000046  0.000056  0.000055
#
# [5 rows x 505 columns]

# %% [markdown]
# ## Eigendecomposition: Equities
#
# Now for the best part - obtaining the eigenvectors from the covariance matrix above:

# %%
eigenvalues, eigenvectors = np.linalg.eig(stocks_cov)

# %%
# Eigenvectors obtained through the decomposition:
for i, v in enumerate(zip( eigenvectors, eigenvalues )):
    # Using the small helper function defined above
    print( f"Dimensionality of vector {i+1}:\t{len( v[ 0 ] )} with value {v[ 1 ]}" )
# Out:
# Dimensionality of vector 1:	505 with value 0.03376173694935515
# Dimensionality of vector 2:	505 with value 0.006176100655963449
# Dimensionality of vector 3:	505 with value 0.0040611287292239085
# Dimensionality of vector 4:	505 with value 0.002543630319584466
# Dimensionality of vector 5:	505 with value 0.0020964649014974693
# Dimensionality of vector 6:	505 with value 0.0017673971316706628
# Dimensionality of vector 7:	505 with value 0.0015192482291482737
# Dimensionality of vector 8:	505 with value 0.0012966572006962178
# Dimensionality of vector 9:	505 with value 0.0012581660613419597
# Dimensionality of vector 10:	505 with value 0.0011673882894033035
# Dimensionality of vector 11:	505 with value 0.0011513412481820259
# Dimensionality of vector 12:	505 with value 0.0010856190395641542
# Dimensionality of vector 13:	505 with value 0.000996023919102303
# Dimensionality of vector 14:	505 with value 0.0009836760831281686
# Dimensionality of vector 15:	505 with value 0.000940458688838092
# Dimensionality of vector 16:	505 with value 0.0009071178448519046
# Dimensionality of vector 17:	505 with value 0.0008868878592446086
# Dimensionality of vector 18:	505 with value 0.0008169311173891984
# Dimensionality of vector 19:	505 with value 0.0008119599698052581
# Dimensionality of vector 20:	505 with value 0.0007871284846455765
# Dimensionality of vector 21:	505 with value 0.0007764245875349436
# Dimensionality of vector 22:	505 with value 0.0007362127175781565
# Dimensionality of vector 23:	505 with value 0.0007118209362591249
# Dimensionality of vector 24:	505 with value 0.0006974929986483579
# Dimensionality of vector 25:	505 with value 0.0006710918344953096
# Dimensionality of vector 26:	505 with value 0.0006587207382353641
# Dimensionality of vector 27:	505 with value 0.0006402271964967737
# Dimensionality of vector 28:	505 with value 0.0006261577747566047
# Dimensionality of vector 29:	505 with value 0.0006029540066125823
# Dimensionality of vector 30:	505 with value 0.0005944609860897757
# Dimensionality of vector 31:	505 with value 0.0005734565131836665
# Dimensionality of vector 32:	505 with value 0.0005704864789587087
# Dimensionality of vector 33:	505 with value 0.0005642643512791077
# Dimensionality of vector 34:	505 with value 0.0005553207868902093
# Dimensionality of vector 35:	505 with value 0.0005308689395747374
# Dimensionality of vector 36:	505 with value 0.0005200959960052241
# Dimensionality of vector 37:	505 with value 0.0005120423280647147
# Dimensionality of vector 38:	505 with value 0.000502630153731112
# Dimensionality of vector 39:	505 with value 0.0004946007850920182
# Dimensionality of vector 40:	505 with value 0.0004766302817312708
# Dimensionality of vector 41:	505 with value 0.00047226114660285797
# Dimensionality of vector 42:	505 with value 0.00045978988740221166
# Dimensionality of vector 43:	505 with value 0.0004562475925232757
# Dimensionality of vector 44:	505 with value 0.0004519338322328118
# Dimensionality of vector 45:	505 with value 0.00044770223276681273
# Dimensionality of vector 46:	505 with value 0.0004381725397433943
# Dimensionality of vector 47:	505 with value 0.00043434639680519347
# Dimensionality of vector 48:	505 with value 0.00042703224019244594
# Dimensionality of vector 49:	505 with value 0.00042259373535547283
# Dimensionality of vector 50:	505 with value 0.0004157276208676624
# Dimensionality of vector 51:	505 with value 0.0004137396756547947
# Dimensionality of vector 52:	505 with value 0.0004070247280150298
# Dimensionality of vector 53:	505 with value 0.0003986849944761665
# Dimensionality of vector 54:	505 with value 0.00039044917740207845
# Dimensionality of vector 55:	505 with value 0.00038503688359826785
# Dimensionality of vector 56:	505 with value 0.0003823765772904199
# Dimensionality of vector 57:	505 with value 0.0003776120160021573
# Dimensionality of vector 58:	505 with value 0.000373653732980865
# Dimensionality of vector 59:	505 with value 0.00036847867230138036
# Dimensionality of vector 60:	505 with value 0.0003628831774905726
# Dimensionality of vector 61:	505 with value 0.00035910605756400954
# Dimensionality of vector 62:	505 with value 0.0003547956925169053
# Dimensionality of vector 63:	505 with value 0.00035101640641110264
# Dimensionality of vector 64:	505 with value 0.00034780711401489507
# Dimensionality of vector 65:	505 with value 0.0003442560393162804
# Dimensionality of vector 66:	505 with value 0.000337109977808632
# Dimensionality of vector 67:	505 with value 0.0003312050869535107
# Dimensionality of vector 68:	505 with value 0.0003307907257321372
# Dimensionality of vector 69:	505 with value 0.00032917879835004857
# Dimensionality of vector 70:	505 with value 0.0003264791633649648
# Dimensionality of vector 71:	505 with value 0.00032620640431549927
# Dimensionality of vector 72:	505 with value 0.00031943551398053334
# Dimensionality of vector 73:	505 with value 0.00031596190236457723
# Dimensionality of vector 74:	505 with value 0.0003115038820114696
# Dimensionality of vector 75:	505 with value 0.0003065321116591662
# Dimensionality of vector 76:	505 with value 0.0003040281341287953
# Dimensionality of vector 77:	505 with value 0.0002991650972076501
# Dimensionality of vector 78:	505 with value 0.0003022115659080318
# Dimensionality of vector 79:	505 with value 0.0002956917504823918
# Dimensionality of vector 80:	505 with value 0.0002912546348981092
# Dimensionality of vector 81:	505 with value 0.00029405463270304683
# Dimensionality of vector 82:	505 with value 0.0002845979312930149
# Dimensionality of vector 83:	505 with value 0.000282577945863912
# Dimensionality of vector 84:	505 with value 0.00027904791560993833
# Dimensionality of vector 85:	505 with value 0.0002657538856832067
# Dimensionality of vector 86:	505 with value 0.00026665167743852126
# Dimensionality of vector 87:	505 with value 0.00026805900468357424
# Dimensionality of vector 88:	505 with value 0.0002709816742930324
# Dimensionality of vector 89:	505 with value 0.00027263750947762323
# Dimensionality of vector 90:	505 with value 0.0002731421192094221
# Dimensionality of vector 91:	505 with value 0.00026343242776039646
# Dimensionality of vector 92:	505 with value 0.0002596275726951833
# Dimensionality of vector 93:	505 with value 0.00025632217494827697
# Dimensionality of vector 94:	505 with value 0.00025391447102519443
# Dimensionality of vector 95:	505 with value 0.0002512526361279121
# Dimensionality of vector 96:	505 with value 0.00024979327766004665
# Dimensionality of vector 97:	505 with value 0.0002468967822591979
# Dimensionality of vector 98:	505 with value 0.00024429702553749566
# Dimensionality of vector 99:	505 with value 0.0002407413537284229
# Dimensionality of vector 100:	505 with value 0.00023791403441231527
# Dimensionality of vector 101:	505 with value 0.00023613751891585053
# Dimensionality of vector 102:	505 with value 0.0002328941220157146
# Dimensionality of vector 103:	505 with value 0.00023180243762251394
# Dimensionality of vector 104:	505 with value 0.00023098767360879745
# Dimensionality of vector 105:	505 with value 0.00022104975585260418
# Dimensionality of vector 106:	505 with value 0.00022852880707024644
# Dimensionality of vector 107:	505 with value 0.00022720074928210462
# Dimensionality of vector 108:	505 with value 0.0002256799533511566
# Dimensionality of vector 109:	505 with value 0.00022434528579807448
# Dimensionality of vector 110:	505 with value 0.00021945453989704686
# Dimensionality of vector 111:	505 with value 0.0002191632441111539
# Dimensionality of vector 112:	505 with value 0.00021675190162163507
# Dimensionality of vector 113:	505 with value 0.00021467271873318547
# Dimensionality of vector 114:	505 with value 0.00021347768673069786
# Dimensionality of vector 115:	505 with value 0.0001996238978721992
# Dimensionality of vector 116:	505 with value 0.0002023781482610247
# Dimensionality of vector 117:	505 with value 0.00020558063942151814
# Dimensionality of vector 118:	505 with value 0.00021003959877881142
# Dimensionality of vector 119:	505 with value 0.0002075125029805391
# Dimensionality of vector 120:	505 with value 0.00020881829220563246
# Dimensionality of vector 121:	505 with value 0.00018413310822226932
# Dimensionality of vector 122:	505 with value 0.00018885173894920364
# Dimensionality of vector 123:	505 with value 0.00019247208196887647
# Dimensionality of vector 124:	505 with value 0.0001958950568844314
# Dimensionality of vector 125:	505 with value 0.0002043558592834592
# Dimensionality of vector 126:	505 with value 0.0001858795938276422
# Dimensionality of vector 127:	505 with value 0.00018660379768129434
# Dimensionality of vector 128:	505 with value 0.00019538847318936771
# Dimensionality of vector 129:	505 with value 0.00019727755769808136
# Dimensionality of vector 130:	505 with value 0.0001897955685890285
# Dimensionality of vector 131:	505 with value 0.0001908054589796897
# Dimensionality of vector 132:	505 with value 0.00018171884518447016
# Dimensionality of vector 133:	505 with value 0.00018058265809292815
# Dimensionality of vector 134:	505 with value 0.00017841029107931229
# Dimensionality of vector 135:	505 with value 0.00017777949950506115
# Dimensionality of vector 136:	505 with value 0.00017646316254882506
# Dimensionality of vector 137:	505 with value 0.00017509227002904511
# Dimensionality of vector 138:	505 with value 0.00017376267571385715
# Dimensionality of vector 139:	505 with value 0.0001715704065024877
# Dimensionality of vector 140:	505 with value 0.0001705032392322126
# Dimensionality of vector 141:	505 with value 0.00016991742579855845
# Dimensionality of vector 142:	505 with value 0.0001685578344788553
# Dimensionality of vector 143:	505 with value 0.00016698090782159766
# Dimensionality of vector 144:	505 with value 0.0001653988077584097
# Dimensionality of vector 145:	505 with value 0.00016451216128821636
# Dimensionality of vector 146:	505 with value 0.00016292030521641553
# Dimensionality of vector 147:	505 with value 0.00016409006580476253
# Dimensionality of vector 148:	505 with value 0.00016066446996775688
# Dimensionality of vector 149:	505 with value 0.00016113966567623926
# Dimensionality of vector 150:	505 with value 0.00015902108538302142
# Dimensionality of vector 151:	505 with value 0.00015840084468611552
# Dimensionality of vector 152:	505 with value 0.00015717384957575017
# Dimensionality of vector 153:	505 with value 0.0001553701080098555
# Dimensionality of vector 154:	505 with value 0.0001538559317734866
# Dimensionality of vector 155:	505 with value 0.00015307087093023106
# Dimensionality of vector 156:	505 with value 0.00015155984998549166
# Dimensionality of vector 157:	505 with value 0.0001508019427225723
# Dimensionality of vector 158:	505 with value 0.0001301871553347149
# Dimensionality of vector 159:	505 with value 0.00013105302647229894
# Dimensionality of vector 160:	505 with value 0.0001482518173527297
# Dimensionality of vector 161:	505 with value 0.00014752513132756676
# Dimensionality of vector 162:	505 with value 0.00014539797193253426
# Dimensionality of vector 163:	505 with value 0.00014567701681337486
# Dimensionality of vector 164:	505 with value 0.00013150623323051984
# Dimensionality of vector 165:	505 with value 0.0001345041047136996
# Dimensionality of vector 166:	505 with value 0.00013286118732864138
# Dimensionality of vector 167:	505 with value 0.000149094851120643
# Dimensionality of vector 168:	505 with value 0.00013209146684612475
# Dimensionality of vector 169:	505 with value 0.00014263414003516813
# Dimensionality of vector 170:	505 with value 0.0001358058613498364
# Dimensionality of vector 171:	505 with value 0.00013778065703353692
# Dimensionality of vector 172:	505 with value 0.0001386097122190912
# Dimensionality of vector 173:	505 with value 0.0001398809064412599
# Dimensionality of vector 174:	505 with value 0.00014069930919570505
# Dimensionality of vector 175:	505 with value 0.00014971295101939993
# Dimensionality of vector 176:	505 with value 0.0001356467310956761
# Dimensionality of vector 177:	505 with value 0.00014164968129753866
# Dimensionality of vector 178:	505 with value 0.00014193626873922565
# Dimensionality of vector 179:	505 with value 0.00012888004314631822
# Dimensionality of vector 180:	505 with value 0.00012867886388782878
# Dimensionality of vector 181:	505 with value 0.00012741560389223846
# Dimensionality of vector 182:	505 with value 0.0001262593395501996
# Dimensionality of vector 183:	505 with value 0.0001258706987412821
# Dimensionality of vector 184:	505 with value 0.0001243009147746667
# Dimensionality of vector 185:	505 with value 0.00012397612189105485
# Dimensionality of vector 186:	505 with value 0.0001232039599350476
# Dimensionality of vector 187:	505 with value 0.0001223076629942866
# Dimensionality of vector 188:	505 with value 0.00012167506363053452
# Dimensionality of vector 189:	505 with value 0.00012079528254060247
# Dimensionality of vector 190:	505 with value 0.00010052201569354404
# Dimensionality of vector 191:	505 with value 0.00011967320443820633
# Dimensionality of vector 192:	505 with value 0.00011876344146628493
# Dimensionality of vector 193:	505 with value 0.0001158333892607902
# Dimensionality of vector 194:	505 with value 0.00011556293402442784
# Dimensionality of vector 195:	505 with value 0.00011447317224904815
# Dimensionality of vector 196:	505 with value 0.0001183584147843807
# Dimensionality of vector 197:	505 with value 0.0001134742772394533
# Dimensionality of vector 198:	505 with value 0.00010157861474969299
# Dimensionality of vector 199:	505 with value 0.00011792866422797536
# Dimensionality of vector 200:	505 with value 0.00010295173362597353
# Dimensionality of vector 201:	505 with value 0.00010379460530309756
# Dimensionality of vector 202:	505 with value 0.00010578459348019271
# Dimensionality of vector 203:	505 with value 0.0001050817177434702
# Dimensionality of vector 204:	505 with value 0.00011769754020112024
# Dimensionality of vector 205:	505 with value 0.00010451401156642223
# Dimensionality of vector 206:	505 with value 0.0001069557109483461
# Dimensionality of vector 207:	505 with value 0.00010775800761384618
# Dimensionality of vector 208:	505 with value 0.00010234426055793862
# Dimensionality of vector 209:	505 with value 0.00011108866012133661
# Dimensionality of vector 210:	505 with value 0.00010903110252443193
# Dimensionality of vector 211:	505 with value 0.00011003987636010048
# Dimensionality of vector 212:	505 with value 0.00010942555127339335
# Dimensionality of vector 213:	505 with value 0.00011033348305222592
# Dimensionality of vector 214:	505 with value 0.00011095130583370531
# Dimensionality of vector 215:	505 with value 0.00010010784005382026
# Dimensionality of vector 216:	505 with value 9.914847906401263e-05
# Dimensionality of vector 217:	505 with value 9.86128756327689e-05
# Dimensionality of vector 218:	505 with value 9.810413169865287e-05
# Dimensionality of vector 219:	505 with value 9.703822411829576e-05
# Dimensionality of vector 220:	505 with value 9.750678296107732e-05
# Dimensionality of vector 221:	505 with value 9.487954968043322e-05
# Dimensionality of vector 222:	505 with value 9.620878658774283e-05
# Dimensionality of vector 223:	505 with value 9.575646736230479e-05
# Dimensionality of vector 224:	505 with value 9.568969606399926e-05
# Dimensionality of vector 225:	505 with value 9.39312389889458e-05
# Dimensionality of vector 226:	505 with value 9.355678920882374e-05
# Dimensionality of vector 227:	505 with value 9.281576154936412e-05
# Dimensionality of vector 228:	505 with value 9.161838888195244e-05
# Dimensionality of vector 229:	505 with value 9.013334628602267e-05
# Dimensionality of vector 230:	505 with value 8.878283442263707e-05
# Dimensionality of vector 231:	505 with value 9.093481472323318e-05
# Dimensionality of vector 232:	505 with value 8.848898600905863e-05
# Dimensionality of vector 233:	505 with value 8.008408044941713e-05
# Dimensionality of vector 234:	505 with value 8.666953958759851e-05
# Dimensionality of vector 235:	505 with value 8.802840595786955e-05
# Dimensionality of vector 236:	505 with value 8.632002806863295e-05
# Dimensionality of vector 237:	505 with value 8.131419367797711e-05
# Dimensionality of vector 238:	505 with value 9.09700381902236e-05
# Dimensionality of vector 239:	505 with value 8.357398088946538e-05
# Dimensionality of vector 240:	505 with value 8.0760475367216e-05
# Dimensionality of vector 241:	505 with value 8.512873446286462e-05
# Dimensionality of vector 242:	505 with value 8.307741520386935e-05
# Dimensionality of vector 243:	505 with value 8.582731279440007e-05
# Dimensionality of vector 244:	505 with value 8.45739215160674e-05
# Dimensionality of vector 245:	505 with value 8.204652056968087e-05
# Dimensionality of vector 246:	505 with value 8.06225749409916e-05
# Dimensionality of vector 247:	505 with value 8.285724344753085e-05
# Dimensionality of vector 248:	505 with value 2.41948516337682e-06
# Dimensionality of vector 249:	505 with value 2.7717728934238618e-06
# Dimensionality of vector 250:	505 with value 4.184458670109786e-06
# Dimensionality of vector 251:	505 with value 4.888397919361824e-06
# Dimensionality of vector 252:	505 with value 7.880189426112047e-05
# Dimensionality of vector 253:	505 with value 7.811364889092292e-05
# Dimensionality of vector 254:	505 with value 7.781872779385495e-05
# Dimensionality of vector 255:	505 with value 7.68513233110159e-05
# Dimensionality of vector 256:	505 with value 7.627125745147976e-05
# Dimensionality of vector 257:	505 with value 7.675277375506664e-05
# Dimensionality of vector 258:	505 with value 7.663665878634663e-05
# Dimensionality of vector 259:	505 with value 7.485346409849097e-05
# Dimensionality of vector 260:	505 with value 7.502236664277829e-05
# Dimensionality of vector 261:	505 with value 7.430797097041965e-05
# Dimensionality of vector 262:	505 with value 7.375698166479052e-05
# Dimensionality of vector 263:	505 with value 7.320503794808704e-05
# Dimensionality of vector 264:	505 with value 7.339296243193468e-05
# Dimensionality of vector 265:	505 with value 7.273359805682976e-05
# Dimensionality of vector 266:	505 with value 7.159731112369759e-05
# Dimensionality of vector 267:	505 with value 7.138450623447561e-05
# Dimensionality of vector 268:	505 with value 7.036299343358157e-05
# Dimensionality of vector 269:	505 with value 6.961634000575633e-05
# Dimensionality of vector 270:	505 with value 7.058035222354465e-05
# Dimensionality of vector 271:	505 with value 7.062166845411571e-05
# Dimensionality of vector 272:	505 with value 6.871695064531707e-05
# Dimensionality of vector 273:	505 with value 6.996726056787557e-05
# Dimensionality of vector 274:	505 with value 6.710640407252954e-05
# Dimensionality of vector 275:	505 with value 6.820082401696509e-05
# Dimensionality of vector 276:	505 with value 6.793713474397769e-05
# Dimensionality of vector 277:	505 with value 6.646600360876981e-05
# Dimensionality of vector 278:	505 with value 6.732857638004191e-05
# Dimensionality of vector 279:	505 with value 6.553853198454213e-05
# Dimensionality of vector 280:	505 with value 6.586359082357289e-05
# Dimensionality of vector 281:	505 with value 6.485847389855517e-05
# Dimensionality of vector 282:	505 with value 6.421943387544225e-05
# Dimensionality of vector 283:	505 with value 6.443117997470901e-05
# Dimensionality of vector 284:	505 with value 5.131455830847027e-06
# Dimensionality of vector 285:	505 with value 5.628290300202007e-06
# Dimensionality of vector 286:	505 with value 5.79120073860098e-06
# Dimensionality of vector 287:	505 with value 8.12274237935131e-06
# Dimensionality of vector 288:	505 with value 6.185708690024185e-06
# Dimensionality of vector 289:	505 with value 6.411951593466613e-06
# Dimensionality of vector 290:	505 with value 6.569912347645202e-06
# Dimensionality of vector 291:	505 with value 6.694762980839739e-06
# Dimensionality of vector 292:	505 with value 6.9629785732955325e-06
# Dimensionality of vector 293:	505 with value 6.392029164188662e-05
# Dimensionality of vector 294:	505 with value 6.345674299928602e-05
# Dimensionality of vector 295:	505 with value 6.280804236167612e-05
# Dimensionality of vector 296:	505 with value 6.232271048910343e-05
# Dimensionality of vector 297:	505 with value 6.179023689640697e-05
# Dimensionality of vector 298:	505 with value 6.157626001346282e-05
# Dimensionality of vector 299:	505 with value 6.125262444221021e-05
# Dimensionality of vector 300:	505 with value 5.9323277659761e-05
# Dimensionality of vector 301:	505 with value 6.066217575579806e-05
# Dimensionality of vector 302:	505 with value 6.036139704123021e-05
# Dimensionality of vector 303:	505 with value 6.018336796782253e-05
# Dimensionality of vector 304:	505 with value 5.8995371174394355e-05
# Dimensionality of vector 305:	505 with value 5.869551295579981e-05
# Dimensionality of vector 306:	505 with value 5.803075450924182e-05
# Dimensionality of vector 307:	505 with value 5.744392622148543e-05
# Dimensionality of vector 308:	505 with value 5.762064087972384e-05
# Dimensionality of vector 309:	505 with value 5.50931446317466e-05
# Dimensionality of vector 310:	505 with value 5.642059681526638e-05
# Dimensionality of vector 311:	505 with value 5.628594964387045e-05
# Dimensionality of vector 312:	505 with value 5.5551051149414643e-05
# Dimensionality of vector 313:	505 with value 5.586793740209204e-05
# Dimensionality of vector 314:	505 with value 5.445607292145864e-05
# Dimensionality of vector 315:	505 with value 5.413833981327574e-05
# Dimensionality of vector 316:	505 with value 4.418913102013045e-05
# Dimensionality of vector 317:	505 with value 4.426472667615699e-05
# Dimensionality of vector 318:	505 with value 4.4707169841806645e-05
# Dimensionality of vector 319:	505 with value 5.3986866599006396e-05
# Dimensionality of vector 320:	505 with value 5.332429046323999e-05
# Dimensionality of vector 321:	505 with value 4.49919327850444e-05
# Dimensionality of vector 322:	505 with value 5.2936432011526544e-05
# Dimensionality of vector 323:	505 with value 5.376338913968303e-05
# Dimensionality of vector 324:	505 with value 5.258833217802636e-05
# Dimensionality of vector 325:	505 with value 4.5185794394796535e-05
# Dimensionality of vector 326:	505 with value 5.2182730243141756e-05
# Dimensionality of vector 327:	505 with value 4.6006288342079386e-05
# Dimensionality of vector 328:	505 with value 4.588457923139898e-05
# Dimensionality of vector 329:	505 with value 4.6582561490535526e-05
# Dimensionality of vector 330:	505 with value 4.71007681087427e-05
# Dimensionality of vector 331:	505 with value 5.079776841476336e-05
# Dimensionality of vector 332:	505 with value 5.1733066416907084e-05
# Dimensionality of vector 333:	505 with value 4.995760890465527e-05
# Dimensionality of vector 334:	505 with value 5.1413213149867945e-05
# Dimensionality of vector 335:	505 with value 5.0574238169955153e-05
# Dimensionality of vector 336:	505 with value 4.774292286858109e-05
# Dimensionality of vector 337:	505 with value 4.9490856170893746e-05
# Dimensionality of vector 338:	505 with value 5.021629535582769e-05
# Dimensionality of vector 339:	505 with value 4.79819627934767e-05
# Dimensionality of vector 340:	505 with value 4.890309267727034e-05
# Dimensionality of vector 341:	505 with value 4.8226906909749375e-05
# Dimensionality of vector 342:	505 with value 4.8661602600785386e-05
# Dimensionality of vector 343:	505 with value 7.365087087506244e-06
# Dimensionality of vector 344:	505 with value 7.229854664519954e-06
# Dimensionality of vector 345:	505 with value 7.652455307306115e-06
# Dimensionality of vector 346:	505 with value 7.81572463626028e-06
# Dimensionality of vector 347:	505 with value 8.243087091413551e-06
# Dimensionality of vector 348:	505 with value 7.87976509229675e-06
# Dimensionality of vector 349:	505 with value 4.2956125593738954e-05
# Dimensionality of vector 350:	505 with value 4.3066738769569564e-05
# Dimensionality of vector 351:	505 with value 4.37716535689395e-05
# Dimensionality of vector 352:	505 with value 4.37376930823461e-05
# Dimensionality of vector 353:	505 with value 8.32806794336661e-06
# Dimensionality of vector 354:	505 with value 8.492878314214574e-06
# Dimensionality of vector 355:	505 with value 8.627444105614609e-06
# Dimensionality of vector 356:	505 with value 8.873666849571105e-06
# Dimensionality of vector 357:	505 with value 8.805751431069841e-06
# Dimensionality of vector 358:	505 with value 9.369589551000171e-06
# Dimensionality of vector 359:	505 with value 9.313643556896539e-06
# Dimensionality of vector 360:	505 with value 4.089800516359618e-05
# Dimensionality of vector 361:	505 with value 4.197841617033492e-05
# Dimensionality of vector 362:	505 with value 4.0320793854644666e-05
# Dimensionality of vector 363:	505 with value 4.2241350347238536e-05
# Dimensionality of vector 364:	505 with value 4.102876549025408e-05
# Dimensionality of vector 365:	505 with value 4.166058916905693e-05
# Dimensionality of vector 366:	505 with value 4.173945541698324e-05
# Dimensionality of vector 367:	505 with value 9.490672676712395e-06
# Dimensionality of vector 368:	505 with value 9.619353301988526e-06
# Dimensionality of vector 369:	505 with value 9.870444090316196e-06
# Dimensionality of vector 370:	505 with value 9.876937421863485e-06
# Dimensionality of vector 371:	505 with value 1.0191851291043273e-05
# Dimensionality of vector 372:	505 with value 1.0405446655021389e-05
# Dimensionality of vector 373:	505 with value 3.998246194483278e-05
# Dimensionality of vector 374:	505 with value 3.969801099088423e-05
# Dimensionality of vector 375:	505 with value 3.923368434342281e-05
# Dimensionality of vector 376:	505 with value 1.0686362544266749e-05
# Dimensionality of vector 377:	505 with value 1.0733324537834949e-05
# Dimensionality of vector 378:	505 with value 3.90085139720007e-05
# Dimensionality of vector 379:	505 with value 3.872337290073969e-05
# Dimensionality of vector 380:	505 with value 3.836622127576084e-05
# Dimensionality of vector 381:	505 with value 3.7561029658417244e-05
# Dimensionality of vector 382:	505 with value 3.7928399904656976e-05
# Dimensionality of vector 383:	505 with value 1.1118244305817971e-05
# Dimensionality of vector 384:	505 with value 1.137801205659171e-05
# Dimensionality of vector 385:	505 with value 1.1172724094791613e-05
# Dimensionality of vector 386:	505 with value 1.102375190155535e-05
# Dimensionality of vector 387:	505 with value 3.670981753015621e-05
# Dimensionality of vector 388:	505 with value 3.7271219021311425e-05
# Dimensionality of vector 389:	505 with value 3.719894697439283e-05
# Dimensionality of vector 390:	505 with value 1.1543771431043344e-05
# Dimensionality of vector 391:	505 with value 3.819248581726191e-05
# Dimensionality of vector 392:	505 with value 1.1759646022835335e-05
# Dimensionality of vector 393:	505 with value 3.605385987626442e-05
# Dimensionality of vector 394:	505 with value 3.6423497125446135e-05
# Dimensionality of vector 395:	505 with value 1.1912851638886308e-05
# Dimensionality of vector 396:	505 with value 1.1661887418126544e-05
# Dimensionality of vector 397:	505 with value 1.2118200811678124e-05
# Dimensionality of vector 398:	505 with value 3.567206303299452e-05
# Dimensionality of vector 399:	505 with value 3.525552067946081e-05
# Dimensionality of vector 400:	505 with value 3.494515830571468e-05
# Dimensionality of vector 401:	505 with value 3.41048615940354e-05
# Dimensionality of vector 402:	505 with value 3.450190743762746e-05
# Dimensionality of vector 403:	505 with value 3.519133596428235e-05
# Dimensionality of vector 404:	505 with value 3.454142212500589e-05
# Dimensionality of vector 405:	505 with value 1.2337270394766248e-05
# Dimensionality of vector 406:	505 with value 3.5082939594258837e-05
# Dimensionality of vector 407:	505 with value 3.345750014717131e-05
# Dimensionality of vector 408:	505 with value 3.3648173865102234e-05
# Dimensionality of vector 409:	505 with value 1.2506491049495759e-05
# Dimensionality of vector 410:	505 with value 1.2563841902547699e-05
# Dimensionality of vector 411:	505 with value 3.3177844167843434e-05
# Dimensionality of vector 412:	505 with value 1.2811723613939081e-05
# Dimensionality of vector 413:	505 with value 1.3057244851406607e-05
# Dimensionality of vector 414:	505 with value 3.286258985345987e-05
# Dimensionality of vector 415:	505 with value 3.2215083790185974e-05
# Dimensionality of vector 416:	505 with value 3.2346348919132734e-05
# Dimensionality of vector 417:	505 with value 3.1798617809457004e-05
# Dimensionality of vector 418:	505 with value 1.3206141188182519e-05
# Dimensionality of vector 419:	505 with value 1.3305842040835184e-05
# Dimensionality of vector 420:	505 with value 3.1549756204981465e-05
# Dimensionality of vector 421:	505 with value 1.3471981997071065e-05
# Dimensionality of vector 422:	505 with value 3.11322847327654e-05
# Dimensionality of vector 423:	505 with value 3.09605307753362e-05
# Dimensionality of vector 424:	505 with value 3.078221321561329e-05
# Dimensionality of vector 425:	505 with value 3.072372213287089e-05
# Dimensionality of vector 426:	505 with value 3.046971032074327e-05
# Dimensionality of vector 427:	505 with value 3.0285374054434568e-05
# Dimensionality of vector 428:	505 with value 3.0288540234282682e-05
# Dimensionality of vector 429:	505 with value 2.9549165321450263e-05
# Dimensionality of vector 430:	505 with value 1.4081618484436328e-05
# Dimensionality of vector 431:	505 with value 1.4200327904178202e-05
# Dimensionality of vector 432:	505 with value 1.464286141268489e-05
# Dimensionality of vector 433:	505 with value 1.4278403851130263e-05
# Dimensionality of vector 434:	505 with value 2.905477250063865e-05
# Dimensionality of vector 435:	505 with value 2.938684440324232e-05
# Dimensionality of vector 436:	505 with value 2.8857182723557678e-05
# Dimensionality of vector 437:	505 with value 2.812204436585404e-05
# Dimensionality of vector 438:	505 with value 2.848381636889298e-05
# Dimensionality of vector 439:	505 with value 2.8743161972799765e-05
# Dimensionality of vector 440:	505 with value 1.3641944591147314e-05
# Dimensionality of vector 441:	505 with value 2.77439136470277e-05
# Dimensionality of vector 442:	505 with value 2.823523764211624e-05
# Dimensionality of vector 443:	505 with value 2.73957146528014e-05
# Dimensionality of vector 444:	505 with value 1.3946261321264876e-05
# Dimensionality of vector 445:	505 with value 1.4853637597498617e-05
# Dimensionality of vector 446:	505 with value 2.7148211846926515e-05
# Dimensionality of vector 447:	505 with value 1.5550125677048008e-05
# Dimensionality of vector 448:	505 with value 2.6988427701516547e-05
# Dimensionality of vector 449:	505 with value 1.5273914275922756e-05
# Dimensionality of vector 450:	505 with value 2.6567925392528666e-05
# Dimensionality of vector 451:	505 with value 2.684369350821295e-05
# Dimensionality of vector 452:	505 with value 1.5730826170931245e-05
# Dimensionality of vector 453:	505 with value 1.488754367078205e-05
# Dimensionality of vector 454:	505 with value 2.616836944867554e-05
# Dimensionality of vector 455:	505 with value 2.6392648230498492e-05
# Dimensionality of vector 456:	505 with value 1.6175008289929886e-05
# Dimensionality of vector 457:	505 with value 1.524377116463401e-05
# Dimensionality of vector 458:	505 with value 2.49030936106714e-05
# Dimensionality of vector 459:	505 with value 2.570360303276105e-05
# Dimensionality of vector 460:	505 with value 2.4629266690029446e-05
# Dimensionality of vector 461:	505 with value 2.5449285294528232e-05
# Dimensionality of vector 462:	505 with value 2.536123314153232e-05
# Dimensionality of vector 463:	505 with value 1.6417475878836224e-05
# Dimensionality of vector 464:	505 with value 1.5968802412140002e-05
# Dimensionality of vector 465:	505 with value 1.592447605246154e-05
# Dimensionality of vector 466:	505 with value 1.6792578271519707e-05
# Dimensionality of vector 467:	505 with value 1.7003534116052882e-05
# Dimensionality of vector 468:	505 with value 2.4007461741097325e-05
# Dimensionality of vector 469:	505 with value 2.372080057300495e-05
# Dimensionality of vector 470:	505 with value 2.334909105442704e-05
# Dimensionality of vector 471:	505 with value 2.3561185158636904e-05
# Dimensionality of vector 472:	505 with value 2.3082970801323665e-05
# Dimensionality of vector 473:	505 with value 1.7197830744656312e-05
# Dimensionality of vector 474:	505 with value 2.187171025666295e-05
# Dimensionality of vector 475:	505 with value 2.2255709308193137e-05
# Dimensionality of vector 476:	505 with value 2.2492250285407567e-05
# Dimensionality of vector 477:	505 with value 2.1572072852255268e-05
# Dimensionality of vector 478:	505 with value 1.7406404226946684e-05
# Dimensionality of vector 479:	505 with value 1.96094018430188e-05
# Dimensionality of vector 480:	505 with value 2.070878700071104e-05
# Dimensionality of vector 481:	505 with value 1.946129410836622e-05
# Dimensionality of vector 482:	505 with value 1.7478207664559086e-05
# Dimensionality of vector 483:	505 with value 1.850662911017021e-05
# Dimensionality of vector 484:	505 with value 1.987870400277392e-05
# Dimensionality of vector 485:	505 with value 2.0531349751848577e-05
# Dimensionality of vector 486:	505 with value 1.8414870469968126e-05
# Dimensionality of vector 487:	505 with value 1.8930738246644687e-05
# Dimensionality of vector 488:	505 with value 2.2878183394108392e-05
# Dimensionality of vector 489:	505 with value 1.8087552449544097e-05
# Dimensionality of vector 490:	505 with value 2.0216585937566063e-05
# Dimensionality of vector 491:	505 with value 1.908095022036916e-05
# Dimensionality of vector 492:	505 with value 2.2759995406623356e-05
# Dimensionality of vector 493:	505 with value 2.09739847132289e-05
# Dimensionality of vector 494:	505 with value 2.1310476743427682e-05
# Dimensionality of vector 495:	505 with value 1.7687885398927384e-05
# Dimensionality of vector 496:	505 with value 1.813410780582345e-05
# Dimensionality of vector 497:	505 with value 1.780691854280651e-05
# Dimensionality of vector 498:	505 with value 1.9982003982113314e-05
# Dimensionality of vector 499:	505 with value 1.8709563745631465e-05
# Dimensionality of vector 500:	505 with value 1.6887872434920774e-05
# Dimensionality of vector 501:	505 with value 2.530645076606773e-05
# Dimensionality of vector 502:	505 with value 2.4357569002852808e-05
# Dimensionality of vector 503:	505 with value 2.1203010611057667e-05
# Dimensionality of vector 504:	505 with value 2.239483807218948e-05
# Dimensionality of vector 505:	505 with value 2.0940927048804248e-05

# %%
eigenvectors[ 0 ]
# Out:
# array([-6.07072279e-02,  5.55305114e-02, -6.55871376e-02,  4.70878629e-03,
#         2.62434287e-02,  7.92773837e-02,  6.82722788e-02,  1.58245110e-01,
#        -2.44580293e-01,  4.74152479e-02,  4.66553310e-02,  1.77453106e-01,
#        -1.46041694e-01, -1.05393971e-02,  1.30534630e-01,  1.07989929e-01,
#        -7.01651531e-02,  2.22378548e-02, -3.19009429e-03,  1.04863787e-01,
#         4.46563897e-02,  1.24465383e-02,  3.16860575e-02,  3.25405076e-02,
#         1.79653337e-02,  4.42303400e-02,  3.69798590e-02,  3.72168400e-02,
#        -1.72988466e-02,  3.25720861e-02, -6.39777227e-02, -2.42724183e-02,
#         1.50596156e-02, -1.99528460e-03, -1.06001928e-02, -3.24210237e-02,
#         5.62660237e-03,  5.19697914e-03, -9.64850336e-03,  1.80889229e-02,
#        -1.27186054e-02,  2.84929759e-02,  5.15552723e-02, -4.07684311e-02,
#        -8.85412813e-02,  8.01000069e-02, -3.97734457e-02,  5.59278623e-02,
#        -7.53187364e-02, -2.76724187e-02,  2.09046697e-02,  5.35706658e-03,
#         3.89759324e-02, -6.50246919e-02, -1.05549601e-02, -1.65956785e-03,
#        -2.16411651e-02, -3.52915696e-02,  2.69843780e-02,  8.73276372e-03,
#        -3.99018872e-02, -3.84875346e-02, -3.37447775e-02,  1.67060258e-02,
#        -6.05944912e-02,  8.43574953e-02, -3.46198770e-02, -5.09291023e-02,
#         1.17212987e-02, -1.43038920e-02,  7.20654163e-03, -3.58500297e-02,
#        -1.56708295e-03,  1.20825521e-02, -1.46256657e-02, -4.40779749e-02,
#        -4.55084607e-02, -2.70190548e-02,  2.22252606e-02, -4.13284607e-02,
#        -1.43418300e-03, -3.96992538e-02, -5.31304140e-02, -1.39392939e-03,
#         6.66530627e-03,  1.96037055e-02, -6.48185214e-02,  2.21098937e-03,
#        -1.95329459e-02,  4.77320133e-02,  1.08660987e-02,  1.98585968e-02,
#         5.35564611e-02,  9.91517158e-03, -2.14030593e-02,  2.83551986e-02,
#        -1.71041448e-02, -3.91448909e-02, -2.69587863e-02, -2.79341397e-02,
#        -3.47959606e-02, -4.87423768e-02,  7.27004320e-02, -1.05368311e-02,
#        -4.81987915e-02,  4.99277010e-02,  5.63946922e-02,  1.01013035e-01,
#        -4.00287887e-02,  1.72201712e-02,  1.32841882e-02,  1.29181727e-02,
#        -7.30542486e-02, -5.98354415e-03, -4.53127981e-02,  4.48440227e-02,
#         6.74516543e-02,  1.41161218e-02, -7.23745782e-02, -4.24690772e-02,
#        -7.60835459e-02,  6.43789472e-02, -3.29933519e-02,  9.40949335e-02,
#         2.77678390e-02, -2.98611476e-02,  2.83519377e-02, -1.69603345e-02,
#        -4.85212646e-03, -2.43146624e-02,  1.44505055e-02, -1.51552794e-02,
#         1.24979787e-02,  7.87382803e-02,  5.30707665e-02, -3.28400406e-02,
#        -8.85551242e-02,  6.95363776e-03,  1.38832345e-01,  2.54500472e-02,
#         1.01935452e-01, -5.30245728e-02,  8.70329717e-03, -4.36563931e-02,
#         2.88208753e-02,  4.80094382e-02, -4.59001203e-03,  1.11084544e-01,
#         5.90175009e-03,  2.42378527e-02, -1.10992127e-01, -6.71565112e-03,
#         6.37660559e-03,  4.51107181e-02,  2.15899951e-02, -7.29979367e-02,
#        -8.08514560e-02, -1.01239720e-01,  1.03420160e-01,  8.32684560e-02,
#         8.05860158e-02,  9.38571723e-02, -6.17651476e-02, -7.30010679e-02,
#        -8.47962091e-02, -2.36383671e-02,  6.09829761e-03, -3.60469830e-02,
#         6.63051827e-02, -8.59828607e-02,  2.15508584e-02, -1.79387915e-02,
#         2.03284197e-02,  4.56974447e-02,  2.41221528e-03, -2.35320148e-02,
#         9.66095213e-03,  6.23916109e-03, -5.05258106e-02,  1.40764056e-02,
#        -4.12300153e-02, -5.11711436e-02,  8.45111283e-03, -3.95777052e-02,
#         2.07168056e-02, -2.23588642e-02,  6.38364528e-02,  6.24804744e-02,
#         1.30351293e-01, -4.22173847e-02,  1.07677147e-01, -4.60562872e-02,
#         3.68362158e-02, -7.09890005e-02, -3.06457667e-02,  4.90917380e-02,
#         2.65246678e-02,  2.13857809e-03, -4.48346032e-02,  4.46923446e-02,
#         3.05969173e-02,  6.29160147e-02,  2.61466030e-02,  2.28677780e-02,
#        -2.42427694e-02,  1.80040361e-02, -2.64369918e-02, -2.46627074e-03,
#        -4.48292141e-02,  1.63214364e-02,  8.47651196e-02,  8.62121955e-03,
#         2.39880899e-02, -1.02004899e-02, -7.73945149e-03, -4.87401705e-02,
#         1.61927851e-02,  3.14588697e-02,  1.26303402e-01,  2.96565403e-03,
#         1.02283881e-01, -2.76129906e-02, -2.95800350e-02, -1.02441210e-02,
#         3.88313475e-03, -1.11958056e-02, -2.13302504e-02,  5.23112331e-02,
#         2.54243036e-02,  4.53460300e-02,  5.83863842e-02,  4.20708615e-02,
#        -6.05493141e-02,  4.09864951e-02,  1.91227685e-02,  3.09215015e-02,
#         9.83578437e-02,  8.84238795e-03, -5.60935417e-02, -8.07090785e-02,
#         5.06721139e-02, -1.16460642e-01,  2.19917644e-02,  2.67932160e-02,
#        -2.20351716e-02, -3.35177843e-02,  1.50028385e-02, -2.90996334e-03,
#         2.78597684e-03, -1.21289297e-02, -2.83006352e-03, -3.41367030e-02,
#         7.24643118e-02, -8.76107014e-02, -6.45140716e-02,  6.07540720e-02,
#         9.81841280e-03, -7.03711136e-04, -8.93624096e-02,  3.98103192e-03,
#        -1.40904608e-02,  5.30688092e-02, -5.17216127e-02,  3.22318282e-02,
#         5.69799450e-02, -2.26131415e-02,  2.46073117e-02, -1.04883614e-01,
#        -5.00703986e-02, -1.26671917e-01, -8.62855253e-02, -3.39617555e-02,
#        -2.79127799e-02, -5.20316891e-02, -2.62384844e-02,  2.95965358e-02,
#         5.27613752e-02,  2.48786738e-02, -4.88510632e-02, -1.68929104e-02,
#         3.99245894e-02, -3.10002362e-02,  8.56327045e-03,  1.14796667e-02,
#         1.64550050e-02, -1.04038703e-02, -3.73631033e-03,  5.66597081e-03,
#         6.82245541e-03,  2.33307105e-02,  2.89292861e-02, -1.22035251e-02,
#        -1.09823223e-02, -9.41489788e-03,  1.72798399e-02, -1.32573410e-02,
#        -6.07381992e-02,  5.47606808e-02, -4.58188607e-02, -3.48474370e-02,
#         3.48007256e-02,  2.81886918e-02, -1.06899937e-02, -2.73299055e-02,
#        -1.89232991e-02, -2.63863615e-02,  2.93042226e-02, -1.85338822e-02,
#         3.90316087e-02,  2.09721260e-02,  3.00893416e-02,  2.44141880e-02,
#        -8.98183928e-03,  3.17184079e-02, -3.68030895e-02, -5.64263996e-02,
#         2.98607146e-02, -1.78739723e-02, -2.78115747e-02, -7.21635341e-02,
#         4.12863126e-02,  6.40304682e-02,  6.48089821e-03, -7.84738145e-02,
#         1.66539385e-02, -3.18261910e-02, -3.60742183e-02, -7.89902908e-02,
#         4.37870476e-02, -1.25696648e-01, -2.22148116e-02, -1.87306776e-03,
#         5.51336361e-02,  5.31085880e-03, -2.50380848e-02,  4.96664082e-03,
#        -3.18074261e-02,  2.62396441e-02,  3.18561973e-02, -2.83998283e-02,
#         1.53617022e-02,  1.12541661e-02,  2.49830101e-02, -5.03176663e-04,
#        -7.65497436e-03,  3.00389874e-02,  1.59749399e-02,  4.24590473e-04,
#        -2.51048132e-02,  2.25029645e-02, -4.58812893e-02,  2.36392203e-02,
#         1.54626390e-03,  6.93006622e-03,  8.44064823e-03,  1.69255429e-02,
#         2.08602097e-03, -1.41999406e-02,  1.28147166e-02, -2.99862111e-02,
#         2.94513356e-02, -2.48806775e-02, -5.38256609e-03,  1.56962880e-02,
#         1.54336128e-02, -1.02377434e-02, -8.42338747e-03,  1.57114019e-02,
#        -2.15383431e-02, -8.66462511e-03,  1.96114769e-02, -1.39888472e-02,
#        -1.82162824e-02,  1.21952197e-02, -4.85603489e-02,  2.65549864e-02,
#         3.15614150e-03, -2.48615115e-02, -2.57817663e-02,  1.11931164e-02,
#        -3.78908721e-02,  1.37934260e-02, -2.60682840e-02, -1.66507374e-02,
#        -5.10647134e-03,  7.03051069e-04,  3.43202230e-03, -1.69832311e-02,
#        -1.17118231e-02,  1.92390813e-02, -1.43086192e-04, -6.37062528e-03,
#        -1.05641397e-02, -7.44047013e-04, -1.60022745e-02, -1.09476274e-03,
#        -3.13332724e-02, -2.20833342e-02,  5.37090917e-02,  1.74446038e-02,
#        -7.94721010e-02, -8.01706946e-02,  2.17672070e-02,  5.56921731e-02,
#         1.83393212e-02,  3.64502616e-03, -3.34861034e-02, -2.01678795e-02,
#         2.35254805e-03,  3.14369095e-03,  1.64815417e-02, -2.04822121e-02,
#         1.04034599e-02,  1.76293410e-03, -1.80514577e-02, -3.51973835e-03,
#         3.84674321e-02, -1.28372620e-02, -1.45434352e-02,  1.86869543e-02,
#        -3.90088288e-02,  5.82656773e-02,  1.11262840e-02, -1.36915993e-02,
#        -1.38426670e-02, -4.22788751e-03,  2.15058616e-02,  2.29637982e-02,
#         2.08687116e-02, -2.42005352e-02, -8.27999147e-03,  2.60460953e-02,
#        -1.22365817e-02,  1.79046822e-02,  3.94551996e-03, -2.77227460e-02,
#        -3.89344063e-02,  5.65515829e-03,  5.56585218e-03,  2.77931500e-03,
#         5.29946415e-03,  4.32090147e-03,  3.24243696e-02, -1.06428875e-03,
#        -3.73761316e-02, -2.54907134e-02, -3.05741281e-02, -3.68762164e-02,
#         4.17535943e-02,  6.77814197e-02,  3.21506791e-02, -1.65792437e-02,
#         3.78918734e-03, -2.13269916e-02, -8.59397745e-03,  1.66731310e-02,
#         2.54845196e-03, -4.68432619e-02, -4.41037761e-03,  1.94794066e-02,
#        -2.95773150e-02, -3.08382553e-02, -3.91786115e-02,  2.31892061e-02,
#         3.13606293e-02, -2.16712811e-02,  1.82154202e-02,  1.58295221e-02,
#         8.45129366e-03, -3.33934558e-02, -2.57888508e-02, -1.65707871e-02,
#         1.27038118e-02,  1.78518345e-02, -1.58152763e-02,  1.63734484e-02,
#         2.89206564e-02,  1.22539830e-02,  2.26109089e-02,  2.69644879e-02,
#        -3.23276487e-02, -3.57148144e-02, -2.52711971e-02,  2.99124761e-02,
#        -2.61956495e-02, -1.81331614e-02,  3.62705517e-02, -2.53843798e-02,
#         2.73635784e-02,  5.23036571e-03,  2.71504717e-03, -7.13528258e-03,
#        -1.77274296e-02,  4.39919011e-03,  4.53838104e-03, -8.78727602e-03,
#        -2.52694365e-03, -3.44741833e-03, -1.11103974e-03,  5.58887583e-04,
#         4.06944121e-03, -2.46090286e-04,  3.02303785e-03, -2.82475628e-03,
#         9.30479160e-04])

# %% [markdown]
# There are as many $(eigenvector, eigenvalue)$ pairs calculated as there are dimensions in the model. Each eigenvector has total elements equal to the number of dimensions. Eigenvectors are sorted in order of decreasing absolute value of the corresponding eigenvalue.
#
# Let's investigate the contribution of each eigenvector to overall variance captured:

# %%
explained_variances = []
for i in range(len(eigenvalues)):
    explained_variances.append(100 * eigenvalues[i] / np.sum(eigenvalues))
 
print(f"Total explained variance = {np.sum(explained_variances)}%\nIndividual explained variances = {explained_variances[0:7]}\n")
# Out:
# Total explained variance = 100.00000000000001%
# Individual explained variances = [26.648161684117927, 4.874800402135243, 3.205451637713862, 2.007689122232974, 1.6547411569489756, 1.395007744875687, 1.1991436491962333]

# %% [markdown]
# ### Decomposition Results
# We see, that the first eigenvector accounts for over 26% of overall variance of S&P500 returns. It is by far the most important component, explaining almost 7x the variance captured by the next best principal component.
#
# Financially speaking, we note that the majority of the overall variance cannot be explained by a linear combination of equity stock returns. 26% is, however, very impressive considering the high dimension size, the complexity of the index and the existence of index weights. This principal component transformation capability is the first interesting finding of our model.
#
# The first principal component could potentially be used for future index return predictions whereby instead of using all 500 underlying equities only this one principal component can be used to reflect index returns with 26% accuracy based on historical returns. S&P500 data availability makes this rather unnecessary.
#
# Note, in this excercise we want to show another interesting application of PCA: to show which are the key equities driving S&P500 returns.

# %% [markdown]
# ## Feature Vector
#
# ### Example
#
# Let's first consider a simplified situation in which there are only two variables which are defining a two-dimensional vector.

# %%
t = np.linspace(0,np.pi*2,100)
plt.axis('equal')
plt.plot(np.cos(t), np.sin(t), linewidth=1, zorder=1)
plt.quiver(0, 0, np.sqrt(2), np.sqrt(2), scale=6, zorder=2)
plt.quiver(0, 0, 0.89, 0.403, scale=3, zorder=2, color='red')

# %% [markdown]
# The key idea is to see that the x-coordinate of the red vector is greater than the y-coordinate. The variable on the x-axis is therefore better placed to capture more of the model variance.
#
# ### More Dimensions
#
# The same idea applies to eigenvectors of higher dimensions in our equities analysis. The key algorithm that we devised is as follows:
#  - Obtain the covariance matrix from underlying data
#  - Extract the **top** eigenvector (feature vector)
#  - Select the several top coordinates by magnitude, i.e. contribution to eigenvector construction
#  - Map these coordinates back to the underlying equities
#  - Retrieve these equities and plot them against the S&P500

# %%
# 1. Take the top eigenvector
# 2. Apply `np.abs` to get the magnitudes of coordinates
# 3. Sort coordinates by magnitudes 
# 4. Retrieve the indices of top 5 equities driving the eigenvector
first_component_drivers = np.abs( eigenvectors[ 0 ] ).argsort()[:5]
first_component_drivers
# Out:
# array([390, 501, 347, 343, 499], dtype=int64)

# %% [markdown]
# We've obtained our array indices which we will now map back to the equities:

# %%
drivers = pivoted_stocks.iloc[:,first_component_drivers]
drivers
# Out:
#                  RCL       YUM       NWL      NTAP       XRX
# date
# 2013-02-08  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-02-11  0.002768 -0.011485 -0.008285 -0.010909  0.003769
# 2013-02-12  0.005796  0.003098  0.010443  0.001414 -0.003755
# 2013-02-13 -0.022777 -0.005251 -0.006614  0.011579  0.005025
# 2013-02-14  0.001404 -0.008073  0.010404  0.001117  0.003750
# ...              ...       ...       ...       ...       ...
# 2018-01-31  0.002026  0.000000  0.027594 -0.013000  0.044370
# 2018-02-01 -0.001797 -0.007211  0.036309  0.010732 -0.040434
# 2018-02-02 -0.027380 -0.016075  0.021168 -0.031210 -0.034198
# 2018-02-05 -0.033087 -0.034249 -0.066476 -0.056626 -0.007904
# 2018-02-06  0.018266  0.009774  0.100689  0.023411 -0.016890
#
# [1258 rows x 5 columns]

# %% [markdown]
# The table above is missing S&P data - let's add it:

# %%
snp['date'] = snp.index.strftime('%Y-%m-%d') # Convert index to proper format
joined = drivers.merge(snp, left_on='date', right_on='date') 
drivers['SNP'] = joined['Close'].values  # Let's ignore that performance warning as the dataset is small.
drivers
# Out:
# C:\Users\Adam\AppData\Local\Temp\ipykernel_19504\2770823921.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drivers['SNP'] = joined['Close'].values  # Let's ignore that performance warning as the dataset is small.
#                  RCL       YUM       NWL      NTAP       XRX       SNP
# date
# 2013-02-08  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-02-11  0.002768 -0.011485 -0.008285 -0.010909  0.003769 -0.000606
# 2013-02-12  0.005796  0.003098  0.010443  0.001414 -0.003755  0.001595
# 2013-02-13 -0.022777 -0.005251 -0.006614  0.011579  0.005025  0.000592
# 2013-02-14  0.001404 -0.008073  0.010404  0.001117  0.003750  0.000691
# ...              ...       ...       ...       ...       ...       ...
# 2018-01-31  0.002026  0.000000  0.027594 -0.013000  0.044370  0.000489
# 2018-02-01 -0.001797 -0.007211  0.036309  0.010732 -0.040434 -0.000648
# 2018-02-02 -0.027380 -0.016075  0.021168 -0.031210 -0.034198 -0.021209
# 2018-02-05 -0.033087 -0.034249 -0.066476 -0.056626 -0.007904 -0.040979
# 2018-02-06  0.018266  0.009774  0.100689  0.023411 -0.016890  0.017441
#
# [1258 rows x 6 columns]

# %% [markdown]
# Above tickers correspond to:
# * **RCL** - Royal Caribbean Cruises Ltd. - world's second-largest cruise holding company
# * **YUM** - Yum! Brands, Inc. - fast food company including KFC, Pizza Hut and Taco Bell brands
# * **NWL** - Newell Brands - manufacturer, marketer and distributor of consumer and commercial products
# * **NTAP** - NetApp, Inc. - hybrid cloud data services and data management company
# * **XRX** - Xerox Holdings Corporation - corporation that sells print and digital document products and services in more than 160 countries
#
# Visualising our results:

# %%
drivers.iloc[0:200].plot(figsize=(25, 10), colormap='plasma', title='Key component equity returns and S&P500 returns (2013)')
# Out:
# <AxesSubplot: title={'center': 'Key component equity returns and S&P500 returns (2013)'}, xlabel='date'>

# %%
drivers.iloc[800:1000].plot(figsize=(25, 10), colormap='plasma', title='Key component equity returns and S&P500 returns (2016)')
# Out:
# <AxesSubplot: title={'center': 'Key component equity returns and S&P500 returns (2016)'}, xlabel='date'>

# %% [markdown]
# ## Findings
#
# * We were able to represent individual returns of equities within the S&P500 index using principal components
# * We found that the most significant principal component explained over 26% of the index's variance
# * We applied additional methodology to extract the top 5 equities driving this main component
# * For the 2013-2018 time period, these spanned large corporations across multiple industries, like tourism, retail & tech
#
#
# * This analysis provides a **simpler and more practical representation** of the returns of all S&P500 constituents
# * It also provides a **framework for extracting key single name equities within principal components** for equity-specific tracking, which saves both analytical and computational resources

# %% [markdown]
# ## References
# * https://towardsdatascience.com/principal-component-analysis-pca-from-scratch-in-python-7f3e2a540c51
# * https://stats.stackexchange.com/questions/143905/loadings-vs-eigenvectors-in-pca-when-to-use-one-or-another
# * https://www.kaggle.com/datasets/camnugent/sandp500
# * https://builtin.com/data-science/step-step-explanation-principal-component-analysis
