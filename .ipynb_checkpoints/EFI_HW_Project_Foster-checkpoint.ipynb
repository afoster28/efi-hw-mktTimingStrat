# %% [markdown]
# # Equity and Fixed Income Homework: P/E Investment Strategy DAX
#
# Author: Adam Foster

# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import yfinance as yf
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # US CAPE-Returns

# %% [markdown]
# ### Data Processing

# %%
raw = pd.read_csv('data_raw.csv', index_col=False, usecols=['Date','P','CAPE'], skiprows=7)

raw.tail()
# Out:
#       Date    P  CAPE
# 2451   NaN  NaN   NaN
# 2452   NaN  NaN   NaN
# 2453   NaN  NaN   NaN
# 2454   NaN  NaN   NaN
# 2455   NaN  NaN   NaN

# %%
data = raw.loc[raw['Date'] < 2016].copy()
data.tail()
# Out:
#          Date        P   CAPE
# 1735  2015.08  2039.87  25.69
# 1736  2015.09  1944.41  24.50
# 1737  2015.10  2024.81  25.49
# 1738  2015.11  2080.62  26.23
# 1739  2015.12  2054.08  25.97

# %%
date_list = raw['Date'].tolist()
shorter_dates = [i for i in date_list if len(str(i)) == 6]
shorter_dates
# Out:
# [1871.1,
#  1872.1,
#  1873.1,
#  1874.1,
#  1875.1,
#  1876.1,
#  1877.1,
#  1878.1,
#  1879.1,
#  1880.1,
#  1881.1,
#  1882.1,
#  1883.1,
#  1884.1,
#  1885.1,
#  1886.1,
#  1887.1,
#  1888.1,
#  1889.1,
#  1890.1,
#  1891.1,
#  1892.1,
#  1893.1,
#  1894.1,
#  1895.1,
#  1896.1,
#  1897.1,
#  1898.1,
#  1899.1,
#  1900.1,
#  1901.1,
#  1902.1,
#  1903.1,
#  1904.1,
#  1905.1,
#  1906.1,
#  1907.1,
#  1908.1,
#  1909.1,
#  1910.1,
#  1911.1,
#  1912.1,
#  1913.1,
#  1914.1,
#  1915.1,
#  1916.1,
#  1917.1,
#  1918.1,
#  1919.1,
#  1920.1,
#  1921.1,
#  1922.1,
#  1923.1,
#  1924.1,
#  1925.1,
#  1926.1,
#  1927.1,
#  1928.1,
#  1929.1,
#  1930.1,
#  1931.1,
#  1932.1,
#  1933.1,
#  1934.1,
#  1935.1,
#  1936.1,
#  1937.1,
#  1938.1,
#  1939.1,
#  1940.1,
#  1941.1,
#  1942.1,
#  1943.1,
#  1944.1,
#  1945.1,
#  1946.1,
#  1947.1,
#  1948.1,
#  1949.1,
#  1950.1,
#  1951.1,
#  1952.1,
#  1953.1,
#  1954.1,
#  1955.1,
#  1956.1,
#  1957.1,
#  1958.1,
#  1959.1,
#  1960.1,
#  1961.1,
#  1962.1,
#  1963.1,
#  1964.1,
#  1965.1,
#  1966.1,
#  1967.1,
#  1968.1,
#  1969.1,
#  1970.1,
#  1971.1,
#  1972.1,
#  1973.1,
#  1974.1,
#  1975.1,
#  1976.1,
#  1977.1,
#  1978.1,
#  1979.1,
#  1980.1,
#  1981.1,
#  1982.1,
#  1983.1,
#  1984.1,
#  1985.1,
#  1986.1,
#  1987.1,
#  1988.1,
#  1989.1,
#  1990.1,
#  1991.1,
#  1992.1,
#  1993.1,
#  1994.1,
#  1995.1,
#  1996.1,
#  1997.1,
#  1998.1,
#  1999.1,
#  2000.1,
#  2001.1,
#  2002.1,
#  2003.1,
#  2004.1,
#  2005.1,
#  2006.1,
#  2007.1,
#  2008.1,
#  2009.1,
#  2010.1,
#  2011.1,
#  2012.1,
#  2013.1,
#  2014.1,
#  2015.1,
#  2016.1,
#  2017.1,
#  2018.1,
#  2019.1,
#  2020.1,
#  2021.1,
#  2022.1]

# %%
data['DateFixed'] = data.apply(lambda x: str(x['Date'])[:4] + '.0' + str(x['Date'])[-1:] if len(str(x['Date'])) == 6 else x['Date'], axis=1)
data.head()
# Out:
#       Date     P  CAPE DateFixed
# 0  1871.01  4.44   NaN   1871.01
# 1  1871.02  4.50   NaN   1871.02
# 2  1871.03  4.61   NaN   1871.03
# 3  1871.04  4.74   NaN   1871.04
# 4  1871.05  4.86   NaN   1871.05

# %%
date_list_new = data['DateFixed'].tolist()
shorter_dates_new = [i for i in date_list_new if len(str(i)) == 6]
shorter_dates_new
# Out:
# []

# %%
data['DateMonth'] = data.apply(lambda x: datetime.datetime.strptime(str(x['DateFixed']), '%Y.%m'), axis = 1).dt.date

# %%
data['Price'] = data.apply(lambda x: float(x['P']), axis=1)

# %%
data = data.drop(['Date','DateFixed','P'], axis=1)

# %% [markdown]
# ### Returns per CAPE Buckets

# %%
data_enhanced = data
data_enhanced['Return_10y'] = ((data_enhanced['Price'].pct_change(120) + 1) ** 0.1) - 1
data_enhanced['Return_1y'] = data_enhanced['Price'].pct_change(12)
data_enhanced['Return_1m'] = ((data_enhanced['Price'].pct_change(1) + 1) ** 12) - 1
# data_enhanced['Return_10y'] = data_enhanced['Price'].pct_change(120)/10
# data_enhanced['Return_1y'] = data_enhanced['Price'].pct_change(12)
# data_enhanced['Return_1m'] = data_enhanced['Price'].pct_change(1)*12

# %%
data_bounded = data_enhanced.loc[data_enhanced['DateMonth'] >= datetime.date(1900, 1, 1)].copy()

# %%
quantiles_full = round(data_bounded[['CAPE']].quantile([0.2, 0.4, 0.6, 0.8]), 1)
quantiles_full
# Out:
#      CAPE
# 0.2  10.6
# 0.4  13.6
# 0.6  17.7
# 0.8  21.8

# %%
def quantiles_condition(x):
    if x['CAPE'] > quantiles_full['CAPE'][0.8]:
        return 'a)Above' + str(quantiles_full['CAPE'][0.8])
    elif x['CAPE'] > quantiles_full['CAPE'][0.6]:
        return 'b)' + str(quantiles_full['CAPE'][0.6]) + 'to' + str(quantiles_full['CAPE'][0.8])
    elif x['CAPE'] > quantiles_full['CAPE'][0.4]:
        return 'c)' + str(quantiles_full['CAPE'][0.4]) + 'to' + str(quantiles_full['CAPE'][0.6])
    elif x['CAPE'] > quantiles_full['CAPE'][0.2]:
        return 'd)' + str(quantiles_full['CAPE'][0.2]) + 'to' + str(quantiles_full['CAPE'][0.4])
    elif x['CAPE'] > 0:
        return 'e)' + 'Below' + str(quantiles_full['CAPE'][0.2])
    else:
        return 'NA'

# %%
data_enhanced['CAPE_Bucket_Full'] = data_enhanced.apply(lambda x: quantiles_condition(x), axis=1)

# %%
data_enhanced['CAPE_Bucket_Full_Lagged_10y'] = data_enhanced[['CAPE_Bucket_Full']].shift(120)

# %%
data_enhanced['Perc_0.2_Roll'] = data_enhanced[['CAPE']].rolling(720, min_periods=1).quantile(0.2)
data_enhanced['Perc_0.4_Roll'] = data_enhanced[['CAPE']].rolling(720, min_periods=1).quantile(0.4)
data_enhanced['Perc_0.6_Roll'] = data_enhanced[['CAPE']].rolling(720, min_periods=1).quantile(0.6)
data_enhanced['Perc_0.8_Roll'] = data_enhanced[['CAPE']].rolling(720, min_periods=1).quantile(0.8)

# %%
def quantiles_roll_condition(x):
    if x['CAPE'] > x['Perc_0.8_Roll']:
        return 1
    elif x['CAPE'] > x['Perc_0.6_Roll']:
        return 2
    elif x['CAPE'] > x['Perc_0.4_Roll']:
        return 3
    elif x['CAPE'] > x['Perc_0.2_Roll']:
        return 4
    elif x['CAPE'] > 0:
        return 5
    else:
        return 0

# %%
data_enhanced['CAPE_Bucket_Roll'] = data_enhanced.apply(lambda x: quantiles_roll_condition(x), axis=1)

# %%
data_enhanced['CAPE_Bucket_Roll_Lagged_10y'] = data_enhanced[['CAPE_Bucket_Roll']].shift(120)
data_enhanced['CAPE_Bucket_Roll_Lagged_1y'] = data_enhanced[['CAPE_Bucket_Roll']].shift(12)
data_enhanced['CAPE_Bucket_Roll_Lagged_1m'] = data_enhanced[['CAPE_Bucket_Roll']].shift(1)

# %%
data_enhanced['EP'] = 1 / data_enhanced['CAPE']

# %%
data_bounded = data_enhanced.loc[data_enhanced['DateMonth'] >= datetime.date(1900, 1, 1)].copy()

# %%
#data_bounded.to_csv('data_bounded.csv')

# %%
data_grouped_full = data_bounded.groupby('CAPE_Bucket_Full_Lagged_10y')['Return_10y'].mean()

# %%
plt.bar(data_grouped_full.keys().tolist(), data_grouped_full.tolist())
plt.title('10y Return Avg Sorted by Starting CAPE')
plt.xlabel('CAPE')
plt.ylabel('Return')
plt.show()

# %%
data_grouped_roll_10y = data_bounded.groupby('CAPE_Bucket_Roll_Lagged_10y')['Return_10y'].mean()
data_grouped_roll_1y = data_bounded.groupby('CAPE_Bucket_Roll_Lagged_1y')['Return_1y'].mean()
data_grouped_roll_1m = data_bounded.groupby('CAPE_Bucket_Roll_Lagged_1m')['Return_1m'].mean()

# %%
data_grouped_roll = pd.concat([data_grouped_roll_10y, data_grouped_roll_1y, data_grouped_roll_1m], axis=1)
data_grouped_roll
# Out:
#      Return_10y  Return_1y  Return_1m
# 1.0    0.026722   0.035296   0.138290
# 2.0    0.054985   0.048485   0.166021
# 3.0    0.074607   0.069423   0.189320
# 4.0    0.072331   0.114090   0.207861
# 5.0    0.056143   0.099980   0.557971

# %%
x = [1, 2, 3, 4, 5]
ret10y = data_grouped_roll['Return_10y'].tolist()
ret1y = data_grouped_roll['Return_1y'].tolist()
ret1m = data_grouped_roll['Return_1m'].tolist()

x_axis = np.arange(len(x))
width = 0.25

plt.bar(x_axis, ret10y, width = width, label = '10y Return')
plt.bar(x_axis + width, ret1y, width = width, label = '1y Return')
plt.bar(x_axis + width * 2, ret1m, width = width, label = '1m Return')

plt.xticks(x_axis, x)
plt.xlabel("CAPE")
plt.ylabel("Return")
plt.title("Return Avg Sorted by Starting CAPE based on Rolling 60y Window")
plt.legend()
plt.show()

# %% [markdown]
# ### Regression

# %%
data_bounded
# Out:
#        CAPE   DateMonth    Price  Return_10y  Return_1y  Return_1m
# 348   18.67  1900-01-01     6.10    0.012639   0.003289   0.171656  \
# 349   18.70  1900-02-01     6.21    0.015589  -0.015848   0.239199
# 350   18.78  1900-03-01     6.26    0.017171  -0.021875   0.101014
# 351   18.94  1900-04-01     6.34    0.016366  -0.021605   0.164606
# 352   18.40  1900-05-01     6.04    0.007233  -0.027375  -0.441051
# ...     ...         ...      ...         ...        ...        ...
# 1735  25.69  2015-08-01  2039.87    0.052380   0.039938  -0.270271
# 1736  24.50  2015-09-01  1944.41    0.047207  -0.024493  -0.437368
# 1737  25.49  2015-01-01  2024.81    0.054417   0.045187   0.626137
# 1738  26.23  2015-11-01  2080.62    0.053342   0.017632   0.385804
# 1739  25.97  2015-12-01  2054.08    0.049913  -0.000092  -0.142775
#
#      CAPE_Bucket_Full CAPE_Bucket_Full_Lagged_10y  Perc_0.2_Roll
# 348      b)17.7to21.8                c)13.6to17.7         15.276  \
# 349      b)17.7to21.8                c)13.6to17.7         15.278
# 350      b)17.7to21.8                c)13.6to17.7         15.280
# 351      b)17.7to21.8                c)13.6to17.7         15.292
# 352      b)17.7to21.8                b)17.7to21.8         15.304
# ...               ...                         ...            ...
# 1735      a)Above21.8                 a)Above21.8         13.144
# 1736      a)Above21.8                 a)Above21.8         13.144
# 1737      a)Above21.8                 a)Above21.8         13.144
# 1738      a)Above21.8                 a)Above21.8         13.144
# 1739      a)Above21.8                 a)Above21.8         13.144
#
#       Perc_0.4_Roll  Perc_0.6_Roll  Perc_0.8_Roll  CAPE_Bucket_Roll
# 348          16.306         17.130         18.204                 1  \
# 349          16.318         17.130         18.222                 1
# 350          16.330         17.130         18.270                 1
# 351          16.342         17.166         18.342                 1
# 352          16.354         17.194         18.384                 1
# ...             ...            ...            ...               ...
# 1735         17.598         20.872         24.872                 1
# 1736         17.598         20.894         24.872                 2
# 1737         17.598         20.900         24.892                 1
# 1738         17.598         20.904         24.944                 1
# 1739         17.598         20.914         24.974                 1
#
#       CAPE_Bucket_Roll_Lagged_10y  CAPE_Bucket_Roll_Lagged_1y
# 348                           2.0                         1.0  \
# 349                           2.0                         1.0
# 350                           2.0                         1.0
# 351                           1.0                         1.0
# 352                           1.0                         1.0
# ...                           ...                         ...
# 1735                          1.0                         1.0
# 1736                          1.0                         1.0
# 1737                          1.0                         1.0
# 1738                          1.0                         1.0
# 1739                          1.0                         1.0
#
#       CAPE_Bucket_Roll_Lagged_1m        EP
# 348                          1.0  0.053562
# 349                          1.0  0.053476
# 350                          1.0  0.053248
# 351                          1.0  0.052798
# 352                          1.0  0.054348
# ...                          ...       ...
# 1735                         1.0  0.038926
# 1736                         1.0  0.040816
# 1737                         2.0  0.039231
# 1738                         1.0  0.038124
# 1739                         1.0  0.038506
#
# [1392 rows x 17 columns]

# %%
#data_bounded.to_csv('data_bounded.csv')

# %%
x = np.array(data_bounded['EP'])
y_10y = np.array(data_bounded['Return_10y'])
y_1y = np.array(data_bounded['Return_1y'])
y_1m = np.array(data_bounded['Return_1m'])

reg_10y_mod = sm.OLS(y_10y, x)
reg_10y = reg_10y_mod.fit()
print(reg_10y.summary())

reg_1y_mod = sm.OLS(y_1y, x)
reg_1y = reg_1y_mod.fit()
print(reg_1y.summary())

reg_1m_mod = sm.OLS(y_1m, x)
reg_1m = reg_1m_mod.fit()
print(reg_1m.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.226
# Model:                            OLS   Adj. R-squared (uncentered):              0.226
# Method:                 Least Squares   F-statistic:                              407.0
# Date:                Mon, 12 Jun 2023   Prob (F-statistic):                    1.33e-79
# Time:                        08:43:32   Log-Likelihood:                          1857.8
# No. Observations:                1392   AIC:                                     -3714.
# Df Residuals:                    1391   BIC:                                     -3708.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.4369      0.022     20.175      0.000       0.394       0.479
# ==============================================================================
# Omnibus:                      103.531   Durbin-Watson:                   0.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.870
# Skew:                          -0.095   Prob(JB):                     9.86e-09
# Kurtosis:                       2.226   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.043
# Model:                            OLS   Adj. R-squared (uncentered):              0.042
# Method:                 Least Squares   F-statistic:                              62.50
# Date:                Mon, 12 Jun 2023   Prob (F-statistic):                    5.38e-15
# Time:                        08:43:32   Log-Likelihood:                          248.76
# No. Observations:                1392   AIC:                                     -495.5
# Df Residuals:                    1391   BIC:                                     -490.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5439      0.069      7.906      0.000       0.409       0.679
# ==============================================================================
# Omnibus:                       58.522   Durbin-Watson:                   0.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              178.997
# Skew:                           0.003   Prob(JB):                     1.35e-39
# Kurtosis:                       4.757   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.006
# Model:                            OLS   Adj. R-squared (uncentered):              0.006
# Method:                 Least Squares   F-statistic:                              8.705
# Date:                Mon, 12 Jun 2023   Prob (F-statistic):                     0.00323
# Time:                        08:43:32   Log-Likelihood:                         -3761.5
# No. Observations:                1392   AIC:                                      7525.
# Df Residuals:                    1391   BIC:                                      7530.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             3.6191      1.227      2.950      0.003       1.213       6.025
# ==============================================================================
# Omnibus:                     3922.003   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         92864472.530
# Skew:                          34.864   Prob(JB):                         0.00
# Kurtosis:                    1266.428   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Germany CAPE-Returns

# %% [markdown]
# ### Data Processing

# %%
raw_dax = yf.download("^GDAXI", start='1988-02-01', end='2023-05-31', interval='1mo')
raw_dax
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close
# Date
# 1988-02-01    951.500000   1091.589966    951.500000   1083.339966  \
# 1988-03-01   1087.319946   1123.270020   1037.260010   1062.329956
# 1988-04-01   1063.280029   1102.329956   1049.170044   1049.170044
# 1988-05-01   1052.839966   1075.660034    994.349976   1075.660034
# 1988-06-01   1095.430054   1138.839966   1095.430054   1133.810059
# ...                  ...           ...           ...           ...
# 2023-01-01  13992.709961  15269.709961  13976.440430  15128.269531
# 2023-02-01  15125.120117  15658.559570  15107.830078  15365.139648
# 2023-03-01  15399.910156  15706.370117  14458.389648  15628.839844
# 2023-04-01  15623.450195  15922.379883  15482.879883  15922.379883
# 2023-05-01  15950.360352  16331.940430  15629.120117  15664.019531
#
#                Adj Close      Volume
# Date
# 1988-02-01   1083.339966           0
# 1988-03-01   1062.329956           0
# 1988-04-01   1049.170044           0
# 1988-05-01   1075.660034           0
# 1988-06-01   1133.810059           0
# ...                  ...         ...
# 2023-01-01  15128.269531  1263845700
# 2023-02-01  15365.139648  1321833900
# 2023-03-01  15628.839844  2329276000
# 2023-04-01  15922.379883  1230000900
# 2023-05-01  15664.019531  1515731000
#
# [424 rows x 6 columns]

# %%
raw_german_cape = pd.read_csv('Historic-cape-ratios.csv', index_col=False)
raw_german_cape
# Out:
#            Date  Germany
# 0    29/01/1982     9.76
# 1    26/02/1982     9.85
# 2    31/03/1982    10.13
# 3    30/04/1982    10.12
# 4    31/05/1982     9.55
# ..          ...      ...
# 492  31/01/2023    18.92
# 493  28/02/2023    18.94
# 494  31/03/2023    19.68
# 495  28/04/2023    20.03
# 496  31/05/2023    19.53
#
# [497 rows x 2 columns]

# %%
def month_end(test_date):
    nxt_mnth = test_date.replace(day=28) + datetime.timedelta(days=4)
    res = nxt_mnth - datetime.timedelta(days=nxt_mnth.day)
    return res

# %%
data_german_cape = raw_german_cape
data_german_cape['DateFormat'] = data_german_cape.apply(lambda x: datetime.datetime.strptime(x['Date'], '%d/%m/%Y'), axis = 1).dt.date
data_german_cape['DateFormatEnd'] = data_german_cape.apply(lambda x: month_end(x['DateFormat']), axis=1)
data_german_cape = data_german_cape.drop(['Date','DateFormat'], axis=1)

# %%
data_dax = raw_dax
data_dax = data_dax[['Close']]
data_dax = data_dax.reset_index()
data_dax['DateFormat'] = data_dax['Date'].dt.date
data_dax['DateFormatShift'] = data_dax.apply(lambda x: x['Date'] - relativedelta(months=1), axis=1)
data_dax['DateFormatShiftEnd'] = data_dax.apply(lambda x: month_end(x['DateFormatShift']), axis=1)
data_dax['DateReformat'] = data_dax['DateFormatShiftEnd'].dt.date
data_dax = data_dax.drop(['Date', 'DateFormat', 'DateFormatShift', 'DateFormatShiftEnd'], axis=1)

# %%
data_germany = data_german_cape.merge(data_dax, how='left', left_on='DateFormatEnd', right_on='DateReformat')
data_germany = data_germany.drop(['DateReformat'], axis=1)
data_germany = data_germany.rename(columns={'Germany': 'CAPE', 'DateFormatEnd': 'Date', 'Close': 'Price'})

# %%
data_germany
# Out:
#       CAPE        Date         Price
# 0     9.76  1982-01-31           NaN
# 1     9.85  1982-02-28           NaN
# 2    10.13  1982-03-31           NaN
# 3    10.12  1982-04-30           NaN
# 4     9.55  1982-05-31           NaN
# ..     ...         ...           ...
# 492  18.92  2023-01-31  15365.139648
# 493  18.94  2023-02-28  15628.839844
# 494  19.68  2023-03-31  15922.379883
# 495  20.03  2023-04-30  15664.019531
# 496  19.53  2023-05-31           NaN
#
# [497 rows x 3 columns]

# %%
#data_germany.to_csv('data_germany.csv')

# %% [markdown]
# ### Returns per CAPE Buckets

# %%
data_enhanced_ger = data_germany
data_enhanced_ger['Return_5y'] = ((data_enhanced_ger['Price'].pct_change(60) + 1) ** 0.2) - 1 # shorter time horizon
data_enhanced_ger['Return_1y'] = data_enhanced_ger['Price'].pct_change(12)
data_enhanced_ger['Return_1m'] = ((data_enhanced_ger['Price'].pct_change(1) + 1) ** 12) - 1

# %%
data_bounded_ger = data_enhanced_ger.loc[(data_enhanced_ger['Date'] >= datetime.date(1993, 1, 1)) & (data_enhanced_ger['Date'] <= datetime.date(2023, 4, 30))].copy() # later start than S&P

# %%
quantiles_full_ger = round(data_bounded_ger[['CAPE']].quantile([0.2, 0.4, 0.6, 0.8]), 1)
quantiles_full_ger
# Out:
#      CAPE
# 0.2  18.8
# 0.4  20.4
# 0.6  22.7
# 0.8  29.5

# %%
def quantiles_condition_ger(x):
    if x['CAPE'] > quantiles_full_ger['CAPE'][0.8]:
        return 'a)Above' + str(quantiles_full_ger['CAPE'][0.8])
    elif x['CAPE'] > quantiles_full_ger['CAPE'][0.6]:
        return 'b)' + str(quantiles_full_ger['CAPE'][0.6]) + 'to' + str(quantiles_full_ger['CAPE'][0.8])
    elif x['CAPE'] > quantiles_full_ger['CAPE'][0.4]:
        return 'c)' + str(quantiles_full_ger['CAPE'][0.4]) + 'to' + str(quantiles_full_ger['CAPE'][0.6])
    elif x['CAPE'] > quantiles_full_ger['CAPE'][0.2]:
        return 'd)' + str(quantiles_full_ger['CAPE'][0.2]) + 'to' + str(quantiles_full_ger['CAPE'][0.4])
    elif x['CAPE'] > 0:
        return 'e)' + 'Below' + str(quantiles_full_ger['CAPE'][0.2])
    else:
        return 'NA'

# %%
data_enhanced_ger['CAPE_Bucket_Full'] = data_enhanced_ger.apply(lambda x: quantiles_condition_ger(x), axis=1)

# %%
data_enhanced_ger['CAPE_Bucket_Full_Lagged_5y'] = data_enhanced_ger[['CAPE_Bucket_Full']].shift(60) #shorter lag at 5yrs

# %%
data_enhanced_ger['Perc_0.2_Roll'] = data_enhanced_ger[['CAPE']].rolling(240, min_periods=1).quantile(0.2) # shorter roll window 20yrs
data_enhanced_ger['Perc_0.4_Roll'] = data_enhanced_ger[['CAPE']].rolling(240, min_periods=1).quantile(0.4)
data_enhanced_ger['Perc_0.6_Roll'] = data_enhanced_ger[['CAPE']].rolling(240, min_periods=1).quantile(0.6)
data_enhanced_ger['Perc_0.8_Roll'] = data_enhanced_ger[['CAPE']].rolling(240, min_periods=1).quantile(0.8)

# %%
data_enhanced_ger['CAPE_Bucket_Roll'] = data_enhanced_ger.apply(lambda x: quantiles_roll_condition(x), axis=1)

# %%
data_enhanced_ger['CAPE_Bucket_Roll_Lagged_5y'] = data_enhanced_ger[['CAPE_Bucket_Roll']].shift(60) # shorter roll window 20yrs
data_enhanced_ger['CAPE_Bucket_Roll_Lagged_1y'] = data_enhanced_ger[['CAPE_Bucket_Roll']].shift(12)
data_enhanced_ger['CAPE_Bucket_Roll_Lagged_1m'] = data_enhanced_ger[['CAPE_Bucket_Roll']].shift(1)

# %%
data_enhanced_ger['EP'] = 1 / data_enhanced_ger['CAPE']

# %%
data_bounded_ger = data_enhanced_ger.loc[(data_enhanced_ger['Date'] >= datetime.date(1993, 1, 1)) & (data_enhanced_ger['Date'] <= datetime.date(2023, 4, 30))].copy() # later start than S&P

# %%
#data_bounded_ger.to_csv('data_bounded_ger.csv')

# %%
data_grouped_full_ger = data_bounded_ger.groupby('CAPE_Bucket_Full_Lagged_5y')['Return_5y'].mean() # reduced to 5yrs

# %%
plt.bar(data_grouped_full_ger.keys().tolist(), data_grouped_full_ger.tolist())
plt.title('5y Return Avg Sorted by Starting CAPE')
plt.xlabel('CAPE')
plt.ylabel('Return')
plt.show()

# %%
data_grouped_roll_5y_ger = data_bounded_ger.groupby('CAPE_Bucket_Roll_Lagged_5y')['Return_5y'].mean()
data_grouped_roll_1y_ger = data_bounded_ger.groupby('CAPE_Bucket_Roll_Lagged_1y')['Return_1y'].mean()
data_grouped_roll_1m_ger = data_bounded_ger.groupby('CAPE_Bucket_Roll_Lagged_1m')['Return_1m'].mean()

# %%
data_grouped_roll_ger = pd.concat([data_grouped_roll_5y_ger, data_grouped_roll_1y_ger, data_grouped_roll_1m_ger], axis=1)
data_grouped_roll_ger
# Out:
#      Return_5y  Return_1y  Return_1m
# 1.0   0.016716   0.153267   0.468558
# 2.0   0.088456   0.004493   0.281207
# 3.0   0.091423   0.034382   0.103803
# 4.0   0.098388   0.122403   0.351031
# 5.0   0.117869   0.217113   0.580733

# %%
x = [1, 2, 3, 4, 5]
ret5y = data_grouped_roll_ger['Return_5y'].tolist() # shorter
ret1y = data_grouped_roll_ger['Return_1y'].tolist()
ret1m = data_grouped_roll_ger['Return_1m'].tolist()

x_axis = np.arange(len(x))
width = 0.25

plt.bar(x_axis, ret5y, width = width, label = '5y Return')
plt.bar(x_axis + width, ret1y, width = width, label = '1y Return')
plt.bar(x_axis + width * 2, ret1m, width = width, label = '1m Return')

plt.xticks(x_axis, x)
plt.xlabel("CAPE")
plt.ylabel("Return")
plt.title("Return Avg Sorted by Starting CAPE based on Rolling 60y Window")
plt.legend()
plt.show()

# %% [markdown]
# ### Regression

# %%
data_bounded_ger
# Out:
#       CAPE        Date         Price  Return_5y  Return_1y  Return_1m
# 132  15.86  1993-01-31   1680.020020   0.091717  -0.038208   1.185668  \
# 133  17.03  1993-02-28   1676.839966   0.095586  -0.024157  -0.022479
# 134  16.90  1993-03-31   1626.829956   0.091690  -0.058596  -0.304645
# 135  16.85  1993-04-30   1627.209961   0.086310  -0.099177   0.002807
# 136  16.24  1993-05-31   1700.930054   0.084499  -0.030781   0.701823
# ..     ...         ...           ...        ...        ...        ...
# 491  17.22  2022-12-31  15128.269531   0.027809  -0.022166   1.706801
# 492  18.92  2023-01-31  15365.139648   0.043211   0.062521   0.204945
# 493  18.94  2023-02-28  15628.839844   0.052572   0.084226   0.226543
# 494  19.68  2023-03-31  15922.379883   0.047717   0.129417   0.250187
# 495  20.03  2023-04-30  15664.019531   0.044414   0.088660  -0.178244
#
#     CAPE_Bucket_Full CAPE_Bucket_Full_Lagged_5y  Perc_0.2_Roll  Perc_0.4_Roll
# 132      e)Below18.8                e)Below18.8         13.784         16.042  \
# 133      e)Below18.8                e)Below18.8         13.826         16.122
# 134      e)Below18.8                e)Below18.8         13.868         16.206
# 135      e)Below18.8                e)Below18.8         13.910         16.290
# 136      e)Below18.8                e)Below18.8         13.912         16.260
# ..               ...                        ...            ...            ...
# 491      e)Below18.8               c)20.4to22.7         18.292         19.706
# 492     d)18.8to20.4               b)22.7to29.5         18.326         19.706
# 493     d)18.8to20.4               c)20.4to22.7         18.386         19.706
# 494     d)18.8to20.4               c)20.4to22.7         18.424         19.706
# 495     d)18.8to20.4               c)20.4to22.7         18.446         19.716
#
#      Perc_0.6_Roll  Perc_0.8_Roll  CAPE_Bucket_Roll
# 132         18.554         21.174                 4  \
# 133         18.516         21.136                 3
# 134         18.468         21.098                 3
# 135         18.420         21.060                 3
# 136         18.408         21.054                 4
# ..             ...            ...               ...
# 491         21.424         23.860                 5
# 492         21.424         23.860                 4
# 493         21.424         23.860                 4
# 494         21.424         23.860                 4
# 495         21.424         23.860                 3
#
#      CAPE_Bucket_Roll_Lagged_5y  CAPE_Bucket_Roll_Lagged_1y
# 132                         4.0                         2.0  \
# 133                         3.0                         2.0
# 134                         3.0                         2.0
# 135                         3.0                         2.0
# 136                         3.0                         2.0
# ..                          ...                         ...
# 491                         3.0                         3.0
# 492                         3.0                         3.0
# 493                         3.0                         4.0
# 494                         3.0                         4.0
# 495                         3.0                         4.0
#
#      CAPE_Bucket_Roll_Lagged_1m        EP
# 132                         4.0  0.063052
# 133                         4.0  0.058720
# 134                         3.0  0.059172
# 135                         3.0  0.059347
# 136                         3.0  0.061576
# ..                          ...       ...
# 491                         4.0  0.058072
# 492                         5.0  0.052854
# 493                         4.0  0.052798
# 494                         4.0  0.050813
# 495                         4.0  0.049925
#
# [364 rows x 17 columns]

# %%
#data_bounded_ger.to_csv('data_bounded_ger.csv')

# %%
x = np.array(data_bounded_ger['EP'])
y_5y = np.array(data_bounded_ger['Return_5y'])
y_1y = np.array(data_bounded_ger['Return_1y'])
y_1m = np.array(data_bounded_ger['Return_1m'])

reg_5y_mod = sm.OLS(y_5y, x)
reg_5y = reg_5y_mod.fit()
print(reg_5y.summary())

reg_1y_mod = sm.OLS(y_1y, x)
reg_1y = reg_1y_mod.fit()
print(reg_1y.summary())

reg_1m_mod = sm.OLS(y_1m, x)
reg_1m = reg_1m_mod.fit()
print(reg_1m.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.275
# Model:                            OLS   Adj. R-squared (uncentered):              0.273
# Method:                 Least Squares   F-statistic:                              137.4
# Date:                Mon, 12 Jun 2023   Prob (F-statistic):                    3.97e-27
# Time:                        08:43:35   Log-Likelihood:                          317.73
# No. Observations:                 364   AIC:                                     -633.5
# Df Residuals:                     363   BIC:                                     -629.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.3557      0.116     11.721      0.000       1.128       1.583
# ==============================================================================
# Omnibus:                       10.275   Durbin-Watson:                   0.037
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.768
# Skew:                           0.416   Prob(JB):                      0.00459
# Kurtosis:                       2.869   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.090
# Model:                            OLS   Adj. R-squared (uncentered):              0.088
# Method:                 Least Squares   F-statistic:                              36.11
# Date:                Mon, 12 Jun 2023   Prob (F-statistic):                    4.54e-09
# Time:                        08:43:36   Log-Likelihood:                          14.870
# No. Observations:                 364   AIC:                                     -27.74
# Df Residuals:                     363   BIC:                                     -23.84
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.5971      0.266      6.009      0.000       1.074       2.120
# ==============================================================================
# Omnibus:                        2.847   Durbin-Watson:                   0.145
# Prob(Omnibus):                  0.241   Jarque-Bera (JB):                2.748
# Skew:                          -0.213   Prob(JB):                        0.253
# Kurtosis:                       3.010   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.118
# Model:                            OLS   Adj. R-squared (uncentered):              0.115
# Method:                 Least Squares   F-statistic:                              48.47
# Date:                Mon, 12 Jun 2023   Prob (F-statistic):                    1.58e-11
# Time:                        08:43:36   Log-Likelihood:                         -523.21
# No. Observations:                 364   AIC:                                      1048.
# Df Residuals:                     363   BIC:                                      1052.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             8.1142      1.166      6.962      0.000       5.822      10.406
# ==============================================================================
# Omnibus:                      307.209   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7062.762
# Skew:                           3.435   Prob(JB):                         0.00
# Kurtosis:                      23.457   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Investment Strategy

# %%
data_enhanced_ger_inv = data_enhanced_ger
data_enhanced_ger_inv['Roll_Median'] = data_enhanced_ger_inv[['EP']].rolling(240, min_periods=1).quantile(0.5)
data_enhanced_ger_inv['Roll_Perc_0.05'] = data_enhanced_ger_inv[['EP']].rolling(240, min_periods=1).quantile(0.05)
data_enhanced_ger_inv['Roll_Perc_0.95'] = data_enhanced_ger_inv[['EP']].rolling(240, min_periods=1).quantile(0.95)
data_enhanced_ger_inv['Return_1m_Log'] = np.log(1 + data_enhanced_ger_inv['Return_1m'])
# data_enhanced_ger_inv['Return_1m_Log'] = np.log(data_enhanced_ger_inv['Price'] / data_enhanced_ger_inv['Price'].shift(1))
data_enhanced_ger_inv['Return_1m_Monthly'] = data_enhanced_ger_inv['Price'].pct_change(1)
data_enhanced_ger_inv['Return_1m_Log_Monthly'] = np.log(1 + data_enhanced_ger_inv['Return_1m_Monthly'])

# %%
libor = pd.read_csv('libor_input_filled.csv', index_col=False)
libor['DateFormat'] = libor.apply(lambda x: datetime.datetime.strptime(str(x['Date']), '%d/%m/%Y'), axis = 1).dt.date
libor['USD_1M_Libor'] = libor['Value'] / 100
libor = libor.drop(['Date', 'Value'], axis=1)
libor = libor.rename(columns={'DateFormat': 'Date'})
libor
# Out:
#              Date  USD_1M_Libor
# 0      1986-01-01       0.08060
# 1      1986-01-02       0.08125
# 2      1986-01-03       0.08125
# 3      1986-01-04       0.08125
# 4      1986-01-05       0.08125
# ...           ...           ...
# 13662  2023-05-29       0.05150
# 13663  2023-05-30       0.05170
# 13664  2023-05-31       0.05190
# 13665  2023-06-01       0.05160
# 13666  2023-06-02       0.05190
#
# [13667 rows x 2 columns]

# %%
data_enhanced_ger_inv = data_enhanced_ger_inv.merge(libor, how='left', on='Date')
data_enhanced_ger_inv
# Out:
#       CAPE        Date         Price  Return_5y  Return_1y  Return_1m
# 0     9.76  1982-01-31           NaN        NaN        NaN        NaN  \
# 1     9.85  1982-02-28           NaN        NaN        NaN        NaN
# 2    10.13  1982-03-31           NaN        NaN        NaN        NaN
# 3    10.12  1982-04-30           NaN        NaN        NaN        NaN
# 4     9.55  1982-05-31           NaN        NaN        NaN        NaN
# ..     ...         ...           ...        ...        ...        ...
# 492  18.92  2023-01-31  15365.139648   0.043211   0.062521   0.204945
# 493  18.94  2023-02-28  15628.839844   0.052572   0.084226   0.226543
# 494  19.68  2023-03-31  15922.379883   0.047717   0.129417   0.250187
# 495  20.03  2023-04-30  15664.019531   0.044414   0.088660  -0.178244
# 496  19.53  2023-05-31           NaN   0.049439   0.225305   0.000000
#
#     CAPE_Bucket_Full CAPE_Bucket_Full_Lagged_5y  Perc_0.2_Roll  Perc_0.4_Roll
# 0        e)Below18.8                       None          9.760          9.760  \
# 1        e)Below18.8                       None          9.778          9.796
# 2        e)Below18.8                       None          9.796          9.832
# 3        e)Below18.8                       None          9.814          9.904
# 4        e)Below18.8                       None          9.718          9.814
# ..               ...                        ...            ...            ...
# 492     d)18.8to20.4               b)22.7to29.5         18.326         19.706
# 493     d)18.8to20.4               c)20.4to22.7         18.386         19.706
# 494     d)18.8to20.4               c)20.4to22.7         18.424         19.706
# 495     d)18.8to20.4               c)20.4to22.7         18.446         19.716
# 496     d)18.8to20.4               c)20.4to22.7         18.446         19.706
#
#      ...  CAPE_Bucket_Roll_Lagged_1y  CAPE_Bucket_Roll_Lagged_1m        EP
# 0    ...                         NaN                         NaN  0.102459  \
# 1    ...                         NaN                         5.0  0.101523
# 2    ...                         NaN                         1.0  0.098717
# 3    ...                         NaN                         1.0  0.098814
# 4    ...                         NaN                         2.0  0.104712
# ..   ...                         ...                         ...       ...
# 492  ...                         3.0                         5.0  0.052854
# 493  ...                         4.0                         4.0  0.052798
# 494  ...                         4.0                         4.0  0.050813
# 495  ...                         4.0                         4.0  0.049925
# 496  ...                         4.0                         3.0  0.051203
#
#      Roll_Median  Roll_Perc_0.05  Roll_Perc_0.95  Return_1m_Log
# 0       0.102459        0.102459        0.102459            NaN  \
# 1       0.101991        0.101570        0.102412            NaN
# 2       0.101523        0.098997        0.102365            NaN
# 3       0.100169        0.098731        0.102319            NaN
# 4       0.101523        0.098736        0.104261            NaN
# ..           ...             ...             ...            ...
# 492     0.048936        0.034157        0.061047       0.186434
# 493     0.048936        0.034157        0.061047       0.204200
# 494     0.048936        0.034157        0.060837       0.223293
# 495     0.048936        0.034157        0.060837      -0.196312
# 496     0.048936        0.034157        0.060837       0.000000
#
#      Return_1m_Monthly  Return_1m_Log_Monthly  USD_1M_Libor
# 0                  NaN                    NaN           NaN
# 1                  NaN                    NaN           NaN
# 2                  NaN                    NaN           NaN
# 3                  NaN                    NaN           NaN
# 4                  NaN                    NaN           NaN
# ..                 ...                    ...           ...
# 492           0.015657               0.015536        0.0457
# 493           0.017162               0.017017        0.0467
# 494           0.018782               0.018608        0.0486
# 495          -0.016226              -0.016359        0.0506
# 496           0.000000               0.000000        0.0519
#
# [497 rows x 24 columns]

# %%
#data_enhanced_ger_inv.to_csv('data_enhanced_ger_inv.csv')

# %%
data_bounded_ger_inv = data_enhanced_ger_inv.loc[(data_enhanced_ger_inv['Date'] >= datetime.date(1993, 1, 1)) & (data_enhanced_ger_inv['Date'] <= datetime.date(2023, 4, 30))].copy()

# %%
data_bounded_ger_inv['Equity_Weight_Init'] = data_bounded_ger_inv.apply(lambda x: min(1.5, max(0.5, 1 + (x['EP'] - x['Roll_Median']) / (x['Roll_Perc_0.95'] - x['Roll_Perc_0.05']))), axis=1)
data_bounded_ger_inv['Equity_Weight'] = data_bounded_ger_inv[['Equity_Weight_Init']].shift(1).fillna(1) # last period's EP-based decision
data_bounded_ger_inv['Cash_Weight'] = 1 - data_bounded_ger_inv['Equity_Weight']
data_bounded_ger_inv['Portfolio'] = data_bounded_ger_inv['Equity_Weight'] * data_bounded_ger_inv['Return_1m_Monthly'] + data_bounded_ger_inv['Cash_Weight'] * data_bounded_ger_inv['USD_1M_Libor']
data_bounded_ger_inv['PortfolioFloor'] = data_bounded_ger_inv.apply(lambda x: max(-0.99, x['Portfolio']), axis=1)
data_bounded_ger_inv['Portfolio_Log'] = np.log(1 + data_bounded_ger_inv['PortfolioFloor'])

# %%
data_bounded_ger_inv
# Out:
#       CAPE        Date         Price  Return_5y  Return_1y  Return_1m
# 132  15.86  1993-01-31   1680.020020   0.091717  -0.038208   1.185668  \
# 133  17.03  1993-02-28   1676.839966   0.095586  -0.024157  -0.022479
# 134  16.90  1993-03-31   1626.829956   0.091690  -0.058596  -0.304645
# 135  16.85  1993-04-30   1627.209961   0.086310  -0.099177   0.002807
# 136  16.24  1993-05-31   1700.930054   0.084499  -0.030781   0.701823
# ..     ...         ...           ...        ...        ...        ...
# 491  17.22  2022-12-31  15128.269531   0.027809  -0.022166   1.706801
# 492  18.92  2023-01-31  15365.139648   0.043211   0.062521   0.204945
# 493  18.94  2023-02-28  15628.839844   0.052572   0.084226   0.226543
# 494  19.68  2023-03-31  15922.379883   0.047717   0.129417   0.250187
# 495  20.03  2023-04-30  15664.019531   0.044414   0.088660  -0.178244
#
#     CAPE_Bucket_Full CAPE_Bucket_Full_Lagged_5y  Perc_0.2_Roll  Perc_0.4_Roll
# 132      e)Below18.8                e)Below18.8         13.784         16.042  \
# 133      e)Below18.8                e)Below18.8         13.826         16.122
# 134      e)Below18.8                e)Below18.8         13.868         16.206
# 135      e)Below18.8                e)Below18.8         13.910         16.290
# 136      e)Below18.8                e)Below18.8         13.912         16.260
# ..               ...                        ...            ...            ...
# 491      e)Below18.8               c)20.4to22.7         18.292         19.706
# 492     d)18.8to20.4               b)22.7to29.5         18.326         19.706
# 493     d)18.8to20.4               c)20.4to22.7         18.386         19.706
# 494     d)18.8to20.4               c)20.4to22.7         18.424         19.706
# 495     d)18.8to20.4               c)20.4to22.7         18.446         19.716
#
#      ...  Return_1m_Log  Return_1m_Monthly  Return_1m_Log_Monthly
# 132  ...       0.781921           0.067330               0.065160  \
# 133  ...      -0.022736          -0.001893              -0.001895
# 134  ...      -0.363333          -0.029824              -0.030278
# 135  ...       0.002803           0.000234               0.000234
# 136  ...       0.531700           0.045305               0.044308
# ..   ...            ...                ...                    ...
# 491  ...       0.995768           0.086521               0.082981
# 492  ...       0.186434           0.015657               0.015536
# 493  ...       0.204200           0.017162               0.017017
# 494  ...       0.223293           0.018782               0.018608
# 495  ...      -0.196312          -0.016226              -0.016359
#
#      USD_1M_Libor  Equity_Weight_Init  Equity_Weight  Cash_Weight  Portfolio
# 132        0.0313            1.109655       1.000000     0.000000   0.067330  \
# 133        0.0319            1.038492       1.109655    -0.109655  -0.005598
# 134        0.0319            1.045100       1.038492    -0.038492  -0.032200
# 135        0.0313            1.047477       1.045100    -0.045100  -0.001168
# 136        0.0325            1.083346       1.047477    -0.047477   0.045913
# ..            ...                 ...            ...          ...        ...
# 491        0.0439            1.339773       1.196516    -0.196516   0.094896
# 492        0.0457            1.145725       1.339773    -0.339773   0.005450
# 493        0.0467            1.143649       1.145725    -0.145725   0.012858
# 494        0.0486            1.070367       1.143649    -0.143649   0.014499
# 495        0.0506            1.037087       1.070367    -0.070367  -0.020929
#
#      PortfolioFloor  Portfolio_Log
# 132        0.067330       0.065160
# 133       -0.005598      -0.005614
# 134       -0.032200      -0.032730
# 135       -0.001168      -0.001168
# 136        0.045913       0.044890
# ..              ...            ...
# 491        0.094896       0.090660
# 492        0.005450       0.005435
# 493        0.012858       0.012776
# 494        0.014499       0.014395
# 495       -0.020929      -0.021151
#
# [364 rows x 30 columns]

# %%
# data_bounded_ger_inv.to_csv('data_bounded_ger_inv.csv')

# %%
date_range = data_bounded_ger_inv['Date'].tolist()
return_1m = data_bounded_ger_inv['Return_1m_Monthly'].tolist()
return_scalar_1m = [i + 1 for i in return_1m]
return_1m_cum_i = 1
return_1m_cum = [(return_1m_cum_i:=return_1m_cum_i*v) for v in return_scalar_1m]

# %%
plt.plot(date_range, return_1m)
plt.title('Monthly Returns: Buy-and-Hold DAX')
plt.show()

# %%
plt.plot(date_range, return_1m_cum)
plt.title('Cumulative Monthly Returns: Buy-and-Hold DAX')
plt.show()

# %%
return_1m_log = data_bounded_ger_inv['Return_1m_Log_Monthly'].tolist()
return_1m_log_cum_i = 0
return_1m_log_cum = [(return_1m_log_cum_i:=return_1m_log_cum_i + v) for v in return_1m_log]

# %%
plt.plot(date_range, return_1m_log_cum)
plt.title('Cumulative Monthly Returns: Buy-and-Hold DAX')
plt.show()

# %%
return_1m_pe = data_bounded_ger_inv['Portfolio'].tolist()
return_scalar_1m_pe = [i + 1 for i in return_1m_pe]
return_1m_pe_cum_i = 1
return_1m_pe_cum = [(return_1m_pe_cum_i:=return_1m_pe_cum_i*v) for v in return_scalar_1m_pe]

# %%
plt.plot(date_range, return_1m_pe)
plt.title('Monthly Returns: P/E Signal Strategy DAX')
plt.show()

# %%
plt.plot(date_range, return_1m_pe_cum)
plt.title('Cumulative Monthly Returns: P/E Signal Strategy DAX')
plt.show()

# %%
return_1m_pe_log = data_bounded_ger_inv['Portfolio_Log'].tolist()
return_1m_pe_log_cum_i = 0
return_1m_pe_log_cum = [(return_1m_pe_log_cum_i:=return_1m_pe_log_cum_i + v) for v in return_1m_pe_log]

# %%
plt.plot(date_range, return_1m_pe_log_cum)
plt.title('Cumulative Monthly Returns: P/E Signal Strategy DAX')
plt.show()

# %%
plt.plot(date_range, return_1m_cum, label='Buy-and-Hold')
plt.plot(date_range, return_1m_pe_cum, label='P/E Signal Strategy')
plt.title('Cumulative Monthly Returns: Buy-and-Hold vs P/E Signal Strategy DAX')
plt.legend()
plt.show()
