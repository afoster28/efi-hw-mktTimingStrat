# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# Read data and apply formatting changes

# %%
raw = pd.read_csv('data_raw.csv', index_col=False, usecols=['Date','P','CAPE'], skiprows=7)

raw.tail()
# Out:
#       Date    P  CAPE
# 2451   NaN  NaN   NaN
# 2452   NaN  NaN   NaN
# 2453   NaN  NaN   NaN
# 2454   NaN  NaN   NaN
# 2455   NaN  NaN   NaN

# %%
data = raw.loc[raw['Date'] < 2016].copy()
data.tail()
# Out:
#          Date        P   CAPE
# 1735  2015.08  2039.87  25.69
# 1736  2015.09  1944.41  24.50
# 1737  2015.10  2024.81  25.49
# 1738  2015.11  2080.62  26.23
# 1739  2015.12  2054.08  25.97

# %%
date_list = raw['Date'].tolist()
shorter_dates = [i for i in date_list if len(str(i)) == 6]
shorter_dates
# Out:
# [1871.1,
#  1872.1,
#  1873.1,
#  1874.1,
#  1875.1,
#  1876.1,
#  1877.1,
#  1878.1,
#  1879.1,
#  1880.1,
#  1881.1,
#  1882.1,
#  1883.1,
#  1884.1,
#  1885.1,
#  1886.1,
#  1887.1,
#  1888.1,
#  1889.1,
#  1890.1,
#  1891.1,
#  1892.1,
#  1893.1,
#  1894.1,
#  1895.1,
#  1896.1,
#  1897.1,
#  1898.1,
#  1899.1,
#  1900.1,
#  1901.1,
#  1902.1,
#  1903.1,
#  1904.1,
#  1905.1,
#  1906.1,
#  1907.1,
#  1908.1,
#  1909.1,
#  1910.1,
#  1911.1,
#  1912.1,
#  1913.1,
#  1914.1,
#  1915.1,
#  1916.1,
#  1917.1,
#  1918.1,
#  1919.1,
#  1920.1,
#  1921.1,
#  1922.1,
#  1923.1,
#  1924.1,
#  1925.1,
#  1926.1,
#  1927.1,
#  1928.1,
#  1929.1,
#  1930.1,
#  1931.1,
#  1932.1,
#  1933.1,
#  1934.1,
#  1935.1,
#  1936.1,
#  1937.1,
#  1938.1,
#  1939.1,
#  1940.1,
#  1941.1,
#  1942.1,
#  1943.1,
#  1944.1,
#  1945.1,
#  1946.1,
#  1947.1,
#  1948.1,
#  1949.1,
#  1950.1,
#  1951.1,
#  1952.1,
#  1953.1,
#  1954.1,
#  1955.1,
#  1956.1,
#  1957.1,
#  1958.1,
#  1959.1,
#  1960.1,
#  1961.1,
#  1962.1,
#  1963.1,
#  1964.1,
#  1965.1,
#  1966.1,
#  1967.1,
#  1968.1,
#  1969.1,
#  1970.1,
#  1971.1,
#  1972.1,
#  1973.1,
#  1974.1,
#  1975.1,
#  1976.1,
#  1977.1,
#  1978.1,
#  1979.1,
#  1980.1,
#  1981.1,
#  1982.1,
#  1983.1,
#  1984.1,
#  1985.1,
#  1986.1,
#  1987.1,
#  1988.1,
#  1989.1,
#  1990.1,
#  1991.1,
#  1992.1,
#  1993.1,
#  1994.1,
#  1995.1,
#  1996.1,
#  1997.1,
#  1998.1,
#  1999.1,
#  2000.1,
#  2001.1,
#  2002.1,
#  2003.1,
#  2004.1,
#  2005.1,
#  2006.1,
#  2007.1,
#  2008.1,
#  2009.1,
#  2010.1,
#  2011.1,
#  2012.1,
#  2013.1,
#  2014.1,
#  2015.1,
#  2016.1,
#  2017.1,
#  2018.1,
#  2019.1,
#  2020.1,
#  2021.1,
#  2022.1]

# %%
data['DateFixed'] = data.apply(lambda x: str(x['Date'])[:4] + '.0' + str(x['Date'])[-1:] if len(str(x['Date'])) == 6 else x['Date'], axis=1)
data.head()
# Out:
#       Date     P  CAPE DateFixed
# 0  1871.01  4.44   NaN   1871.01
# 1  1871.02  4.50   NaN   1871.02
# 2  1871.03  4.61   NaN   1871.03
# 3  1871.04  4.74   NaN   1871.04
# 4  1871.05  4.86   NaN   1871.05

# %%
date_list_new = data['DateFixed'].tolist()
shorter_dates_new = [i for i in date_list_new if len(str(i)) == 6]
shorter_dates_new
# Out:
# []

# %%
data['DateMonth'] = data.apply(lambda x: datetime.datetime.strptime(str(x['DateFixed']), '%Y.%m'), axis = 1).dt.date

# %%
data['Price'] = data.apply(lambda x: float(x['P']), axis=1)

# %%
data = data.drop(['Date','DateFixed','P'], axis=1)

# %% [markdown]
# Calculate returns and lagged CAPE bucket columns

# %%
data_enhanced = data
data_enhanced['Return_10y'] = data_enhanced['Price'].pct_change(120)/10
data_enhanced['Return_1y'] = data_enhanced['Price'].pct_change(12)
data_enhanced['Return_1m'] = data_enhanced['Price'].pct_change(1)*12

# %%
quantiles_full = round(data_bounded[['CAPE']].quantile([0.2, 0.4, 0.6, 0.8], numeric_only = True), 1)
quantiles_full
# Out:
#      CAPE
# 0.2  10.6
# 0.4  13.6
# 0.6  17.7
# 0.8  21.8

# %%
def quantiles_condition(x):
    if x['CAPE'] > quantiles_full['CAPE'][0.8]:
        return 'a)Above' + str(quantiles_full['CAPE'][0.8])
    elif x['CAPE'] > quantiles_full['CAPE'][0.6]:
        return 'b)' + str(quantiles_full['CAPE'][0.6]) + 'to' + str(quantiles_full['CAPE'][0.8])
    elif x['CAPE'] > quantiles_full['CAPE'][0.4]:
        return 'c)' + str(quantiles_full['CAPE'][0.4]) + 'to' + str(quantiles_full['CAPE'][0.6])
    elif x['CAPE'] > quantiles_full['CAPE'][0.2]:
        return 'd)' + str(quantiles_full['CAPE'][0.2]) + 'to' + str(quantiles_full['CAPE'][0.4])
    elif x['CAPE'] > 0:
        return 'e)' + 'Below' + str(quantiles_full['CAPE'][0.2])
    else:
        return 'NA'

# %%
data_enhanced['CAPE_Bucket_Full'] = data_enhanced.apply(lambda x: quantiles_condition(x), axis=1)

# %%
data_enhanced['CAPE_Bucket_Full_Lagged_10y'] = data_enhanced[['CAPE_Bucket_Full']].shift(120)

# %%
data_bounded = data_enhanced.loc[data_enhanced['DateMonth'] >= datetime.date(1900, 1, 1)].copy()

# %%
data_bounded
# Out:
#        CAPE   DateMonth    Price  Return_10y  Return_1y  Return_1m
# 348   18.67  1900-01-01     6.10    0.013383   0.003289   0.159468  \
# 349   18.70  1900-02-01     6.21    0.016729  -0.015848   0.216393
# 350   18.78  1900-03-01     6.26    0.018561  -0.021875   0.096618
# 351   18.94  1900-04-01     6.34    0.017625  -0.021605   0.153355
# 352   18.40  1900-05-01     6.04    0.007473  -0.027375  -0.567823
# ...     ...         ...      ...         ...        ...        ...
# 1735  25.69  2015-08-01  2039.87    0.066619   0.039938  -0.310982
# 1736  24.50  2015-09-01  1944.41    0.058608  -0.024493  -0.561565
# 1737  25.49  2015-01-01  2024.81    0.069872   0.045187   0.496192
# 1738  26.23  2015-11-01  2080.62    0.068149   0.017632   0.330757
# 1739  25.97  2015-12-01  2054.08    0.062755  -0.000092  -0.153070
#
#      CAPE_Bucket_Full CAPE_Bucket_Full_Lagged_10y
# 348      b)17.7to21.8                c)13.6to17.7
# 349      b)17.7to21.8                c)13.6to17.7
# 350      b)17.7to21.8                c)13.6to17.7
# 351      b)17.7to21.8                c)13.6to17.7
# 352      b)17.7to21.8                b)17.7to21.8
# ...               ...                         ...
# 1735      a)Above21.8                 a)Above21.8
# 1736      a)Above21.8                 a)Above21.8
# 1737      a)Above21.8                 a)Above21.8
# 1738      a)Above21.8                 a)Above21.8
# 1739      a)Above21.8                 a)Above21.8
#
# [1392 rows x 8 columns]

# %%
data_grouped = data_bounded.groupby('CAPE_Bucket_Full_Lagged_10y')['Return_10y'].mean()

# %%
plt.bar(data_grouped.keys().tolist(), data_grouped.tolist())
plt.title('10y Return Avg Sorted by Starting CAPE')
plt.xlabel('CAPE')
plt.ylabel('Return')
plt.show()
